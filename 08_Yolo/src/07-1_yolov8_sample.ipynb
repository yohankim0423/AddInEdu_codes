# %%
from ultralytics import YOLO

model = YOLO('yolov8n-seg.pt')

results = model.train(data='/Users/yohan/Desktop/dev_ws/yolo/data/Sample/01.원천데이터/08_174514_221206/sensor_raw_data/camera/YOLODataset/dataset.yaml', epochs=100, imgsz=640, batch=4)
# Out:
# Ultralytics YOLOv8.2.18 🚀 Python-3.10.14 torch-2.3.0 CPU (Apple M3 Pro)
# ...

# %%
from ultralytics import YOLO

results = model.predict(source="/Users/yohan/Desktop/dev_ws/yolo/data/Sample/01.원천데이터/08_174514_221206/sensor_raw_data/camera", conf=0.2, save=True)

print(results)
# Out:
# image 1/40 /Users/yohan/Desktop/dev_ws/yolo/data/Sample/01.원천데이터/08_174514_221206/sensor_raw_data/camera/08_174514_221206_01.jpg: 384x640 3 lanes, 62.0ms
# image 2/40 /Users/yohan/Desktop/dev_ws/yolo/data/Sample/01.원천데이터/08_174514_221206/sensor_raw_data/camera/08_174514_221206_02.jpg: 384x640 5 lanes, 50.6ms
# image 3/40 /Users/yohan/Desktop/dev_ws/yolo/data/Sample/01.원천데이터/08_174514_221206/sensor_raw_data/camera/08_174514_221206_03.jpg: 384x640 4 lanes, 60.6ms
# image 4/40 /Users/yohan/Desktop/dev_ws/yolo/data/Sample/01.원천데이터/08_174514_221206/sensor_raw_data/camera/08_174514_221206_04.jpg: 384x640 4 lanes, 65.1ms
# image 5/40 /Users/yohan/Desktop/dev_ws/yolo/data/Sample/01.원천데이터/08_174514_221206/sensor_raw_data/camera/08_174514_221206_05.jpg: 384x640 3 lanes, 61.0ms
# image 6/40 /Users/yohan/Desktop/dev_ws/yolo/data/Sample/01.원천데이터/08_174514_221206/sensor_raw_data/camera/08_174514_221206_06.jpg: 384x640 2 lanes, 55.0ms
# ...
