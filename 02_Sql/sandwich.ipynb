# %%
import mysql.connector

local = mysql.connector.connect(
    host = "localhost",
    user = "root",
    password = "0032"
)

# %%
remote = mysql.connector.connect(
    host = "database-1.c5my42wsuuxn.ap-northeast-2.rds.amazonaws.com",
    port = 3306,
    user = "root",
    password = "00320032"
)

# %%
local.close()

# %%
remote.close()

# %%
import mysql.connector

local = mysql.connector.connect(
    host = "localhost",
    port = 3306,
    user = "root",
    password = "0032",
    database = "armbase"
)

local.close()

# %%
remote = mysql.connector.connect(
    host = "database-1.c5my42wsuuxn.ap-northeast-2.rds.amazonaws.com",
    port = 3306,
    user = "root",
    password = "00320032",
    database = "armbase"
)

remote.close()

# %%
remote = mysql.connector.connect(
    host = "database-1.c5my42wsuuxn.ap-northeast-2.rds.amazonaws.com",
    port = 3306,
    user = "root",
    password = "00320032",
    database = "armbase"
)

cur = remote.cursor()
cur.execute("CREATE TABLE sql_file (id int, filename varchar(16))")

remote.close()
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~/venv/eda_venv/lib/python3.10/site-packages/mysql/connector/connection_cext.py:661, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     660         query = query.encode("utf-8")
# --> 661     self._cmysql.query(
#     662         query,
#     663         raw=raw,
#     664         buffered=buffered,
#     665         raw_as_string=raw_as_string,
#     666         query_attrs=self.query_attrs,
#     667     )
#     668 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Table 'sql_file' already exists
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[28], line 10
#       1 remote = mysql.connector.connect(
#       2     host = "database-1.c5my42wsuuxn.ap-northeast-2.rds.amazonaws.com",
#       3     port = 3306,
#    (...)
#       6     database = "armbase"
#       7 )
#       9 cur = remote.cursor()
# ---> 10 cur.execute("CREATE TABLE sql_file (id int, filename varchar(16))")
#      12 remote.close()
#
# File ~/venv/eda_venv/lib/python3.10/site-packages/mysql/connector/cursor_cext.py:374, in CMySQLCursor.execute(self, operation, params, multi)
#     369             raise ProgrammingError(
#     370                 "Not all parameters were used in the SQL statement"
#     371             )
#     373 try:
# --> 374     result = self._cnx.cmd_query(
#     375         stmt,
#     376         raw=self._raw,
#     377         buffered=self._buffered,
#     378         raw_as_string=self._raw_as_string,
#     379     )
#     380 except MySQLInterfaceError as err:
#     381     raise get_mysql_exception(
#     382         msg=err.msg, errno=err.errno, sqlstate=err.sqlstate
#     383     ) from err
#
# File ~/venv/eda_venv/lib/python3.10/site-packages/mysql/connector/opentelemetry/context_propagation.py:74, in with_context_propagation.<locals>.wrapper(cnx, *args, **kwargs)
#      72 """Context propagation decorator."""
#      73 if not OTEL_ENABLED or not cnx.otel_context_propagation:
# ---> 74     return method(cnx, *args, **kwargs)
#      76 current_span = trace.get_current_span()
#      77 tp_header = None
#
# File ~/venv/eda_venv/lib/python3.10/site-packages/mysql/connector/connection_cext.py:669, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     661     self._cmysql.query(
#     662         query,
#     663         raw=raw,
#    (...)
#     666         query_attrs=self.query_attrs,
#     667     )
#     668 except MySQLInterfaceError as err:
# --> 669     raise get_mysql_exception(
#     670         err.errno, msg=err.msg, sqlstate=err.sqlstate
#     671     ) from err
#     672 except AttributeError as err:
#     673     addr = (
#     674         self._unix_socket if self._unix_socket else f"{self._host}:{self._port}"
#     675     )
#
# ProgrammingError: 1050 (42S01): Table 'sql_file' already exists

# %%
remote = mysql.connector.connect(
    host = "database-1.c5my42wsuuxn.ap-northeast-2.rds.amazonaws.com",
    port = 3306,
    user = "root",
    password = "00320032",
    database = "armbase"
)

cur = remote.cursor()
cur.execute("DROP TABLE sql_file")

remote.close()

# %%
remote = mysql.connector.connect(
    host = "database-1.c5my42wsuuxn.ap-northeast-2.rds.amazonaws.com",
    port = 3306,
    user = "root",
    password = "00320032",
    database = "armbase"
)

cur = remote.cursor()
sql = open("test03.sql").read()
cur.execute(sql)

remote.close()

# %%
remote = mysql.connector.connect(
    host = "database-1.c5my42wsuuxn.ap-northeast-2.rds.amazonaws.com",
    port = 3306,
    user = "root",
    password = "00320032",
    database = "armbase"
)
cur = remote.cursor()
sql = open("test04.sql").read()
cur.execute(sql)

remote.close()

# %%
remote = mysql.connector.connect(
    host = "database-1.c5my42wsuuxn.ap-northeast-2.rds.amazonaws.com",
    port = 3306,
    user = "root",
    password = "00320032",
    database = "armbase"
)
cur = remote.cursor()
sql = open("test04.sql").read()
for result_iterator in cur.execute(sql, multi=True):
    if result_iterator.with_rows:
        print(result_iterator.fetchall())
    else:
        print(result_iterator.statement)

remote.commit()
remote.close()
# Out:
# INSERT INTO sql_file VALUES (1, "test01.sql")
# INSERT INTO sql_file VALUES (2, "test02.sql")
# INSERT INTO sql_file VALUES (3, "test03.sql")
# INSERT INTO sql_file VALUES (4, "test04.sql")

# %%
remote = mysql.connector.connect(
    host = "database-1.c5my42wsuuxn.ap-northeast-2.rds.amazonaws.com",
    port = 3306,
    user = "root",
    password = "00320032",
    database = "armbase"
)

cur = remote.cursor(buffered=True)
cur.execute("SELECT * FROM sql_file")

result = cur.fetchall()
for result_iterator in result:
    print(result_iterator)

remote.close()
# Out:
# (1, 'test01.sql')
# (2, 'test02.sql')
# (3, 'test03.sql')
# (4, 'test04.sql')

# %%
import pandas as pd

df = pd.DataFrame(result)
df.head()
# Out:
# /tmp/ipykernel_12476/1839875721.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
#    0           1
# 0  1  test01.sql
# 1  2  test02.sql
# 2  3  test03.sql
# 3  4  test04.sql

# %%
import pandas as pd

df = pd.read_csv("sandwich.csv")
df.head()
# Out:
# /tmp/ipykernel_18069/3822179754.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
#    Rank                    Cafe               Menu  Price              Address
# 0     1             Old Oak Tap                BLT   10.0  2109 W. Chicago Ave
# 1     2               Au Cheval      Fried Bologna    9.0   800 W. Randolph St
# 2     3                    Xoco  Woodland Mushroom    9.5      445 N. Clark St
# 3     4               Al’s Deli         Roast Beef    9.4         914 Noyes St
# 4     5  Publican Quality Meats               PB&L   10.0    825 W. Fulton Mkt

# %%
import mysql.connector

conn = mysql.connector.connect(
    host = "database-1.c5my42wsuuxn.ap-northeast-2.rds.amazonaws.com",
    port = 3306,
    user = "root",
    password = "00320032",
    database = "armbase"
)

# %%
sql = "CREATE TABLE sandwich (rand int, cafe varchar(32), menu varchar(32), price float, address varchar(32))"
cursor = conn.cursor(buffered=True)
cursor.execute(sql)

# %%
cursor = conn.cursor(buffered=True)

# %%
sql = "INSERT INTO sandwich VALUES (%s, %s, %s, %s, %s)"

# %%
for i, row in df.iterrows():
    cursor.execute(sql, tuple(row))
    print(tuple(row))
    conn.commit()
# Out:
# (1, 'Old Oak Tap', 'BLT', 10.0, '2109 W. Chicago Ave')
# (2, 'Au Cheval', 'Fried Bologna', 9.0, '800 W. Randolph St')
# (3, 'Xoco', 'Woodland Mushroom', 9.5, ' 445 N. Clark St')
# (4, 'Al’s Deli', 'Roast Beef', 9.4, ' 914 Noyes St')
# (5, 'Publican Quality Meats', 'PB&L', 10.0, '825 W. Fulton Mkt')
# (6, 'Hendrickx Belgian Bread Crafter', 'Belgian Chicken Curry Salad', 7.25, ' 100 E. Walton St')
# (7, 'Acadia', 'Lobster Roll', 16.0, '1639 S. Wabash Ave')
# (8, 'Birchwood Kitchen', 'Smoked Salmon Salad', 10.0, '2211 W. North Ave')
# (9, 'Cemitas Puebla', 'Atomica Cemitas', 9.0, '3619 W. North Ave')
# (10, 'Nana', 'Grilled Laughing Bird Shrimp and Fried Po’ Boy', 17.0, '3267 S. Halsted St')
# (11, 'Lula Cafe', 'Ham and Raclette Panino', 11.0, '2537 N. Kedzie Blvd')
# (12, 'Ricobene’s', 'Breaded Steak', 5.49, ' Multiple location')
# (13, 'Frog n Snail', 'The Hawkeye', 14.0, '3124 N. Broadwa')
# (14, 'Crosby’s Kitchen', 'Chicken Dip', 10.0, '3455 N. Southport Ave')
# (15, 'Longman & Eagle', 'Wild Boar Sloppy Joe', 13.0, '2657 N. Kedzie Ave')
# (16, 'Bari', 'Meatball Sub', 4.5, ' 1120 W. Grand Ave')
# (17, 'Manny’s', 'Corned Beef', 11.95, ' 1141 S. Jefferson St')
# (18, 'Eggy’s', 'Turkey Club', 11.5, ' 333 E. Benton Pl')
# (19, 'Old Jerusalem', 'Falafel', 6.25, ' 1411 N. Wells St')
# (20, 'Mindy’s HotChocolate', 'Crab Cake', 15.0, '1747 N. Damen Ave')
# (21, 'Olga’s Delicatessen', 'Chicken Schnitzel', 5.0, '3209 W. Irving Park Rd')
# (22, 'Dawali Mediterranean Kitchen', 'Shawarma', 6.0, 'Multiple location')
# (23, 'Big Jones', 'Toasted Pimiento Cheese', 8.0, '5347 N. Clark St')
# (24, 'La Pane', 'Vegetarian Panino', 5.99, ' 2954 W. Irving Park Rd')
# (25, 'Pastoral', 'Cali Chèvre', 7.52, ' Multiple location')
# (26, 'Max’s Deli', 'Pastrami', 11.95, ' 191 Skokie Valley Rd')
# (27, 'Lucky’s Sandwich Co.', 'The Fredo', 7.5, ' Multiple location')
# (28, 'City Provisions', 'Smoked Ham', 12.95, ' 1818 W. Wilson Ave')
# (29, 'Papa’s Cache Sabroso', 'Jibarito', 7.0, '2517 W. Division St')
# (30, 'Bavette’s Bar & Boeuf', 'Shaved Prime Rib', 21.0, '218 W. Kinzie St')
# (31, 'Hannah’s Bretzel', 'Serrano Ham and Manchego Cheese', 9.79, ' Multiple location')
# (32, 'La Fournette', 'Tuna Salad', 9.75, ' 1547 N. Wells St')
# (33, 'Paramount Room', 'Paramount Reuben', 13.0, '415 N. Milwaukee Ave')
# (34, 'Melt Sandwich Shoppe', 'The Istanbul', 7.95, ' 1840 N. Damen Ave')
# (35, 'Floriole Cafe & Bakery', 'B.A.D.', 9.0, '1220 W. Webster Ave')
# (36, 'First Slice Pie Café', 'Duck Confit and Mozzarella', 9.0, '5357 N. Ashland Ave')
# (37, 'Troquet', 'Croque Monsieur', 8.0, '1834 W. Montrose Ave')
# (38, 'Grahamwich', 'Green Garbanzo', 8.0, '615 N. State St')
# (39, 'Saigon Sisters', 'The Hen House', 7.0, 'Multiple location')
# (40, 'Rosalia’s Deli', 'Tuscan Chicken', 6.0, '241 N. York Rd')
# (41, 'Z&H MarketCafe', 'The Marty ', 7.25, ' 1323 E. 57th St')
# (42, 'Market House on the Square', 'Whitefish', 11.0, '655 Forest Ave')
# (43, 'Elaine’s Coffee Call', 'Oat Bread, Pecan Butter, and Fruit Jam', 6.0, 'Hotel Lincol')
# (44, 'Marion Street Cheese Market', 'Cauliflower Melt', 9.0, '100 S. Marion St')
# (45, 'Cafecito', 'Cubana', 5.49, ' 26 E. Congress Pkwy')
# (46, 'Chickpea', 'Kufta', 8.0, '2018 W. Chicago Ave')
# (47, 'The Goddess and Grocer', 'Debbie’s Egg Salad', 6.5, ' 25 E. Delaware Pl')
# (48, 'Zenwich', 'Beef Curry', 7.5, ' 416 N. York St')
# (49, 'Toni Patisserie', 'Le Végétarien', 8.75, ' 65 E. Washington St')
# (50, 'Phoebe’s Bakery', 'The Gatsby', 6.85, ' 3351 N. Broadwa')

# %%
cursor.execute("SELECT * FROM sandwich")

result = cursor.fetchall()
for row in result:
    print(row)
# Out:
# (1, 'Old Oak Tap', 'BLT', 10.0, '2109 W. Chicago Ave')
# (2, 'Au Cheval', 'Fried Bologna', 9.0, '800 W. Randolph St')
# (3, 'Xoco', 'Woodland Mushroom', 9.5, ' 445 N. Clark St')
# (4, 'Al’s Deli', 'Roast Beef', 9.4, ' 914 Noyes St')
# (5, 'Publican Quality Meats', 'PB&L', 10.0, '825 W. Fulton Mkt')
# (6, 'Hendrickx Belgian Bread Crafter', 'Belgian Chicken Curry Salad', 7.25, ' 100 E. Walton St')
# (7, 'Acadia', 'Lobster Roll', 16.0, '1639 S. Wabash Ave')
# (8, 'Birchwood Kitchen', 'Smoked Salmon Salad', 10.0, '2211 W. North Ave')
# (9, 'Cemitas Puebla', 'Atomica Cemitas', 9.0, '3619 W. North Ave')
# (10, 'Nana', 'Grilled Laughing Bird Shrimp and', 17.0, '3267 S. Halsted St')
# (11, 'Lula Cafe', 'Ham and Raclette Panino', 11.0, '2537 N. Kedzie Blvd')
# (12, 'Ricobene’s', 'Breaded Steak', 5.49, ' Multiple location')
# (13, 'Frog n Snail', 'The Hawkeye', 14.0, '3124 N. Broadwa')
# (14, 'Crosby’s Kitchen', 'Chicken Dip', 10.0, '3455 N. Southport Ave')
# (15, 'Longman & Eagle', 'Wild Boar Sloppy Joe', 13.0, '2657 N. Kedzie Ave')
# (16, 'Bari', 'Meatball Sub', 4.5, ' 1120 W. Grand Ave')
# (17, 'Manny’s', 'Corned Beef', 11.95, ' 1141 S. Jefferson St')
# (18, 'Eggy’s', 'Turkey Club', 11.5, ' 333 E. Benton Pl')
# (19, 'Old Jerusalem', 'Falafel', 6.25, ' 1411 N. Wells St')
# (20, 'Mindy’s HotChocolate', 'Crab Cake', 15.0, '1747 N. Damen Ave')
# (21, 'Olga’s Delicatessen', 'Chicken Schnitzel', 5.0, '3209 W. Irving Park Rd')
# (22, 'Dawali Mediterranean Kitchen', 'Shawarma', 6.0, 'Multiple location')
# (23, 'Big Jones', 'Toasted Pimiento Cheese', 8.0, '5347 N. Clark St')
# (24, 'La Pane', 'Vegetarian Panino', 5.99, ' 2954 W. Irving Park Rd')
# (25, 'Pastoral', 'Cali Chèvre', 7.52, ' Multiple location')
# (26, 'Max’s Deli', 'Pastrami', 11.95, ' 191 Skokie Valley Rd')
# (27, 'Lucky’s Sandwich Co.', 'The Fredo', 7.5, ' Multiple location')
# (28, 'City Provisions', 'Smoked Ham', 12.95, ' 1818 W. Wilson Ave')
# (29, 'Papa’s Cache Sabroso', 'Jibarito', 7.0, '2517 W. Division St')
# (30, 'Bavette’s Bar & Boeuf', 'Shaved Prime Rib', 21.0, '218 W. Kinzie St')
# (31, 'Hannah’s Bretzel', 'Serrano Ham and Manchego Cheese', 9.79, ' Multiple location')
# (32, 'La Fournette', 'Tuna Salad', 9.75, ' 1547 N. Wells St')
# (33, 'Paramount Room', 'Paramount Reuben', 13.0, '415 N. Milwaukee Ave')
# (34, 'Melt Sandwich Shoppe', 'The Istanbul', 7.95, ' 1840 N. Damen Ave')
# (35, 'Floriole Cafe & Bakery', 'B.A.D.', 9.0, '1220 W. Webster Ave')
# (36, 'First Slice Pie Café', 'Duck Confit and Mozzarella', 9.0, '5357 N. Ashland Ave')
# (37, 'Troquet', 'Croque Monsieur', 8.0, '1834 W. Montrose Ave')
# (38, 'Grahamwich', 'Green Garbanzo', 8.0, '615 N. State St')
# (39, 'Saigon Sisters', 'The Hen House', 7.0, 'Multiple location')
# (40, 'Rosalia’s Deli', 'Tuscan Chicken', 6.0, '241 N. York Rd')
# (41, 'Z&H MarketCafe', 'The Marty ', 7.25, ' 1323 E. 57th St')
# (42, 'Market House on the Square', 'Whitefish', 11.0, '655 Forest Ave')
# (43, 'Elaine’s Coffee Call', 'Oat Bread, Pecan Butter, and Fru', 6.0, 'Hotel Lincol')
# (44, 'Marion Street Cheese Market', 'Cauliflower Melt', 9.0, '100 S. Marion St')
# (45, 'Cafecito', 'Cubana', 5.49, ' 26 E. Congress Pkwy')
# (46, 'Chickpea', 'Kufta', 8.0, '2018 W. Chicago Ave')
# (47, 'The Goddess and Grocer', 'Debbie’s Egg Salad', 6.5, ' 25 E. Delaware Pl')
# (48, 'Zenwich', 'Beef Curry', 7.5, ' 416 N. York St')
# (49, 'Toni Patisserie', 'Le Végétarien', 8.75, ' 65 E. Washington St')
# (50, 'Phoebe’s Bakery', 'The Gatsby', 6.85, ' 3351 N. Broadwa')

# %%
df = pd.DataFrame(result)
df
# Out:
#      0                                1                                 2  \
# 0    1                      Old Oak Tap                               BLT
# 1    2                        Au Cheval                     Fried Bologna
# 2    3                             Xoco                 Woodland Mushroom
# 3    4                        Al’s Deli                        Roast Beef
# 4    5           Publican Quality Meats                              PB&L
# 5    6  Hendrickx Belgian Bread Crafter       Belgian Chicken Curry Salad
# 6    7                           Acadia                      Lobster Roll
# 7    8                Birchwood Kitchen               Smoked Salmon Salad
# 8    9                   Cemitas Puebla                   Atomica Cemitas
# 9   10                             Nana  Grilled Laughing Bird Shrimp and
# 10  11                        Lula Cafe           Ham and Raclette Panino
# 11  12                       Ricobene’s                     Breaded Steak
# 12  13                     Frog n Snail                       The Hawkeye
# 13  14                 Crosby’s Kitchen                       Chicken Dip
# 14  15                  Longman & Eagle              Wild Boar Sloppy Joe
# 15  16                             Bari                      Meatball Sub
# 16  17                          Manny’s                       Corned Beef
# 17  18                           Eggy’s                       Turkey Club
# 18  19                    Old Jerusalem                           Falafel
# 19  20             Mindy’s HotChocolate                         Crab Cake
# 20  21              Olga’s Delicatessen                 Chicken Schnitzel
# 21  22     Dawali Mediterranean Kitchen                          Shawarma
# 22  23                        Big Jones           Toasted Pimiento Cheese
# 23  24                          La Pane                 Vegetarian Panino
# 24  25                         Pastoral                       Cali Chèvre
# 25  26                       Max’s Deli                          Pastrami
# 26  27             Lucky’s Sandwich Co.                         The Fredo
# 27  28                  City Provisions                        Smoked Ham
# 28  29             Papa’s Cache Sabroso                          Jibarito
# 29  30            Bavette’s Bar & Boeuf                  Shaved Prime Rib
# 30  31                 Hannah’s Bretzel   Serrano Ham and Manchego Cheese
# 31  32                     La Fournette                        Tuna Salad
# 32  33                   Paramount Room                  Paramount Reuben
# 33  34             Melt Sandwich Shoppe                      The Istanbul
# 34  35           Floriole Cafe & Bakery                            B.A.D.
# 35  36             First Slice Pie Café        Duck Confit and Mozzarella
# 36  37                          Troquet                   Croque Monsieur
# 37  38                       Grahamwich                    Green Garbanzo
# 38  39                   Saigon Sisters                     The Hen House
# 39  40                   Rosalia’s Deli                    Tuscan Chicken
# 40  41                   Z&H MarketCafe                        The Marty
# 41  42       Market House on the Square                         Whitefish
# 42  43             Elaine’s Coffee Call  Oat Bread, Pecan Butter, and Fru
# 43  44      Marion Street Cheese Market                  Cauliflower Melt
# 44  45                         Cafecito                            Cubana
# 45  46                         Chickpea                             Kufta
# 46  47           The Goddess and Grocer                Debbie’s Egg Salad
# 47  48                          Zenwich                        Beef Curry
# 48  49                  Toni Patisserie                     Le Végétarien
# 49  50                  Phoebe’s Bakery                        The Gatsby
#
#         3                        4
# 0   10.00      2109 W. Chicago Ave
# 1    9.00       800 W. Randolph St
# 2    9.50          445 N. Clark St
# 3    9.40             914 Noyes St
# 4   10.00        825 W. Fulton Mkt
# 5    7.25         100 E. Walton St
# 6   16.00       1639 S. Wabash Ave
# 7   10.00        2211 W. North Ave
# 8    9.00        3619 W. North Ave
# 9   17.00       3267 S. Halsted St
# 10  11.00      2537 N. Kedzie Blvd
# 11   5.49        Multiple location
# 12  14.00          3124 N. Broadwa
# 13  10.00    3455 N. Southport Ave
# 14  13.00       2657 N. Kedzie Ave
# 15   4.50        1120 W. Grand Ave
# 16  11.95     1141 S. Jefferson St
# 17  11.50         333 E. Benton Pl
# 18   6.25         1411 N. Wells St
# 19  15.00        1747 N. Damen Ave
# 20   5.00   3209 W. Irving Park Rd
# 21   6.00        Multiple location
# 22   8.00         5347 N. Clark St
# 23   5.99   2954 W. Irving Park Rd
# 24   7.52        Multiple location
# 25  11.95     191 Skokie Valley Rd
# 26   7.50        Multiple location
# 27  12.95       1818 W. Wilson Ave
# 28   7.00      2517 W. Division St
# 29  21.00         218 W. Kinzie St
# 30   9.79        Multiple location
# 31   9.75         1547 N. Wells St
# 32  13.00     415 N. Milwaukee Ave
# 33   7.95        1840 N. Damen Ave
# 34   9.00      1220 W. Webster Ave
# 35   9.00      5357 N. Ashland Ave
# 36   8.00     1834 W. Montrose Ave
# 37   8.00          615 N. State St
# 38   7.00        Multiple location
# 39   6.00           241 N. York Rd
# 40   7.25          1323 E. 57th St
# 41  11.00           655 Forest Ave
# 42   6.00             Hotel Lincol
# 43   9.00         100 S. Marion St
# 44   5.49      26 E. Congress Pkwy
# 45   8.00      2018 W. Chicago Ave
# 46   6.50        25 E. Delaware Pl
# 47   7.50           416 N. York St
# 48   8.75      65 E. Washington St
# 49   6.85          3351 N. Broadwa
