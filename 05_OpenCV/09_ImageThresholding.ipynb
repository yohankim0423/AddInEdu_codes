# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread('/home/verlo/dev_ws/OpenCV/data/rainbow.jpg')
print('type(img) = {type(img)}, img.shape = {img.shape}')
plt.imshow(img);
# Out:
# type(img) = {type(img)}, img.shape = {img.shape}

# %%
img = cv2.imread('/home/verlo/dev_ws/OpenCV/data/rainbow.jpg', cv2.IMREAD_GRAYSCALE)
plt.imshow(img);

# %%
plt.imshow(img, cmap='gray')

# %%
ret, thresh1 = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY)
print(ret)

plt.subplot(1, 2, 1)
plt.imshow(img, cmap='gray')
plt.subplot(1, 2, 2)
plt.imshow(thresh1, cmap='gray')
plt.show()
# Out:
# 127.0

# %%
ret, thresh1 = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY_INV)
print(ret)

plt.subplot(1, 2, 1)
plt.imshow(img, cmap='gray')
plt.subplot(1, 2, 1)
plt.imshow(thresh1, cmap='gray')
plt.show()
# Out:
# 127.0

# %%
ret, thresh1 = cv2.threshold(img, 127, 255, cv2.THRESH_TRUNC)
print(ret)

plt.subplot(1, 2, 1)
plt.imshow(img, cmap='gray')
plt.subplot(1, 2, 2)
plt.imshow(thresh1, cmap='gray')
plt.show()
# Out:
# 127.0

# %%
ret, thresh1 = cv2.threshold(img, 127, 255, cv2.THRESH_TOZERO_INV)
print(ret)

plt.subplot(1, 2, 1)
plt.imshow(img, cmap='gray')
plt.subplot(1, 2, 2)
plt.imshow(thresh1, cmap='gray')
plt.show()
# Out:
# 127.0

# %%
img = cv2.imread('/home/verlo/dev_ws/OpenCV/data/crossword.jpg', 0)
print(f'type(img) = {type(img)}, img.shape = {img.shape}')
plt.imshow(img, cmap='gray');
# Out:
# type(img) = <class 'numpy.ndarray'>, img.shape = (374, 606)

# %%
show_pic(img)

# %%
ret, thresh1 = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY)
show_pic(thresh1)

# %%
ret, thresh1 = cv2.threshold(img, 180, 255, cv2.THRESH_BINARY)
print(ret)
show_pic(thresh1)
# Out:
# 180.0

# %%
img = cv2.imread('/home/verlo/dev_ws/OpenCV/data/crossword.jpg', 0)
print(f'type(img) = {type(img)}, img.shape = {img.shape}')
# Out:
# type(img) = <class 'numpy.ndarray'>, img.shape = (374, 606)

# %%
img.dtype
# Out:
# dtype('uint8')

# %%
img.shape
# Out:
# (374, 606)

# %%
thresh2 = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 11, 8)
show_pic(thresh2)

# %%
blended = cv2.addWeighted(src1 = thresh1, alpha = 0.6, src2 = thresh2, beta=0.4, gamma=0)
show_pic(blended)

# %%
thresh2 = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 11, 8)
show_pic(thresh2)

# %%
blended = cv2.addWeighted(src1 = thresh1, alpha = 0.6, src2 = thresh2, beta=0.4, gamma=0)
show_pic(blended)
