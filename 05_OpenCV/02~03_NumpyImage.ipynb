# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
img = cv2.imread('/home/verlo/dev_ws/OpenCV/data/test.jpg')
type(img)
# Out:
# numpy.ndarray

# %%
tmp = cv2.imread('./mmmm.jpg')
type(tmp)
# Out:
# [ WARN:0@4.696] global loadsave.cpp:248 findDecoder imread_('./mmmm.jpg'): can't open/read file: check file path/integrity
# NoneType

# %%
img.shape
# Out:
# (960, 540, 3)

# %%
plt.imshow(img)

# %%
fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(fix_img);

# %%
img_gray = cv2.imread('/home/verlo/dev_ws/OpenCV/data/test.jpg', cv2.IMREAD_GRAYSCALE)
plt.imshow(img_gray, cmap='gray');

# %%
img.shape
# Out:
# (960, 540, 3)

# %%
new_img = cv2.resize(fix_img, (800, 600))
plt.imshow(new_img);

# %%
plt.imshow(cv2.flip(fix_img, 0));

# %%
plt.imshow(cv2.flip(fix_img, 1));

# %%
plt.imshow(cv2.flip(fix_img, -1));

# %%
plt.imshow(img_gray, cmap='gray');

# %%
cv2.imwrite('/home/verlo/dev_ws/OpenCV/data/pw_gray.jpg', img_gray)
# Out:
# True
