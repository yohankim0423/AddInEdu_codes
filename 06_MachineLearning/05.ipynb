# %%
import pandas as pd

# %%
df = pd.DataFrame(
    {
        'A' : ['a', 'b', 'c', 'a', 'b'],
        'B' : [1, 2, 3, 1, 0]
    }
)

df
# Out:
#    A  B
# 0  a  1
# 1  b  2
# 2  c  3
# 3  a  1
# 4  b  0

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
le.fit(df['A'])
# Out:
# LabelEncoder()

# %%
le.classes_
# Out:
# array(['a', 'b', 'c'], dtype=object)

# %%
df['le_A'] = le.transform(df['A'])
df
# Out:
#    A  B  le_A
# 0  a  1     0
# 1  b  2     1
# 2  c  3     2
# 3  a  1     0
# 4  b  0     1

# %%
le.transform(['a', 'b'])
# Out:
# array([0, 1])

# %%
le.fit_transform(df['A'])
# Out:
# array([0, 1, 2, 0, 1])

# %%
le.inverse_transform([1, 2, 2, 2])
# Out:
# array(['b', 'c', 'c', 'c'], dtype=object)

# %%
df = pd.DataFrame(
    {
        'A' : [10, 20, -10, 0, 25],
        'B' : [1, 2, 3, 1, 0]
    }
)

df
# Out:
#     A  B
# 0  10  1
# 1  20  2
# 2 -10  3
# 3   0  1
# 4  25  0

# %%
from sklearn.preprocessing import MinMaxScaler

mms = MinMaxScaler()
mms.fit(df)
# Out:
# MinMaxScaler()

# %%
mms.data_max_, mms.data_min_
# Out:
# (array([25.,  3.]), array([-10.,   0.]))

# %%
df_mms = mms.transform(df)
df_mms
# Out:
# array([[0.57142857, 0.33333333],
#        [0.85714286, 0.66666667],
#        [0.        , 1.        ],
#        [0.28571429, 0.33333333],
#        [1.        , 0.        ]])

# %%
mms.inverse_transform(df_mms)
# Out:
# array([[ 10.,   1.],
#        [ 20.,   2.],
#        [-10.,   3.],
#        [  0.,   1.],
#        [ 25.,   0.]])

# %%
mms.fit_transform(df)
# Out:
# array([[0.57142857, 0.33333333],
#        [0.85714286, 0.66666667],
#        [0.        , 1.        ],
#        [0.28571429, 0.33333333],
#        [1.        , 0.        ]])

# %%
df
# Out:
#     A  B
# 0  10  1
# 1  20  2
# 2 -10  3
# 3   0  1
# 4  25  0

# %%
from sklearn.preprocessing import StandardScaler

ss = StandardScaler()
ss.fit(df)
# Out:
# StandardScaler()

# %%
ss.mean_, ss.scale_
# Out:
# (array([9. , 1.4]), array([12.80624847,  1.0198039 ]))

# %%
df_ss = ss.transform(df)
df_ss
# Out:
# array([[ 0.07808688, -0.39223227],
#        [ 0.85895569,  0.58834841],
#        [-1.48365074,  1.56892908],
#        [-0.70278193, -0.39223227],
#        [ 1.2493901 , -1.37281295]])

# %%
ss.inverse_transform(df_ss)
# Out:
# array([[ 10.,   1.],
#        [ 20.,   2.],
#        [-10.,   3.],
#        [  0.,   1.],
#        [ 25.,   0.]])

# %%
df = pd.DataFrame(
    {
        'A' :[-0.1, 0., 0.2, 0.3, 0.4, 1.0, 1.1, 5]
    }
)

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler

mm = MinMaxScaler()
ss = StandardScaler()
rs = RobustScaler()

# %%
df_scaler = df.copy()

# %%
df_scaler['MinMax'] = mm.fit_transform(df)
df_scaler['Standard'] = ss.fit_transform(df)
df_scaler['Robust'] = rs.fit_transform(df)

# %%
df_scaler
# Out:
#      A    MinMax  Standard    Robust
# 0 -0.1  0.000000 -0.692859 -0.514286
# 1  0.0  0.019608 -0.629148 -0.400000
# 2  0.2  0.058824 -0.501725 -0.171429
# 3  0.3  0.078431 -0.438014 -0.057143
# 4  0.4  0.098039 -0.374303  0.057143
# 5  1.0  0.215686  0.007964  0.742857
# 6  1.1  0.235294  0.071675  0.857143
# 7  5.0  1.000000  2.556410  5.314286

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="whitegrid")
plt.figure(figsize=(16, 6))
sns.boxplot(data=df_scaler, orient="h");
