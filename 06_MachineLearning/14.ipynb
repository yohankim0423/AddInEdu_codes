# %%
import pandas as pd

url = 'https://github.com/PinkWink/ML_tutorial/raw/master/dataset/HAR_dataset/features.txt'
feature_name_df = pd.read_csv(url, sep='\s+', header=None, names=['column_index', 'coulumn_name'])
feature_name = feature_name_df.iloc[:, 1].values.tolist()

# %%
X_train_url = 'https://github.com/PinkWink/ML_tutorial/raw/master/dataset/HAR_dataset/train/X_train.txt'
X_test_url = 'https://github.com/PinkWink/ML_tutorial/raw/master/dataset/HAR_dataset/test/X_test.txt'

X_train = pd.read_csv(X_train_url, sep='\s+', header=None)
X_test = pd.read_csv(X_test_url, sep='\s+', header=None)

X_train.columns = feature_name
X_test.columns = feature_name

y_train_url = 'https://github.com/PinkWink/ML_tutorial/raw/master/dataset/HAR_dataset/train/y_train.txt'
y_test_url = 'https://github.com/PinkWink/ML_tutorial/raw/master/dataset/HAR_dataset/test/y_test.txt'

y_train = pd.read_csv(y_train_url, sep='\s+', header=None, names=['action'])
y_test = pd.read_csv(y_test_url, sep='\s+', header=None, names=['action'])

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((7352, 561), (2947, 561), (7352, 1), (2947, 1))

# %%
from sklearn.decomposition import PCA

def get_pca_data(ss_data, n_components=2):
    pca = PCA(n_components=n_components)
    pca.fit(ss_data)

    return pca.transform(ss_data), pca

# %%
HAR_pca, pca = get_pca_data(X_train, n_components=2)
HAR_pca.shape
# Out:
# (7352, 2)

# %%
pca.mean_.shape, pca.components_.shape
# Out:
# ((561,), (2, 561))

# %%
cols = ['pca_'+str(n) for n in range(pca.components_.shape[0])]
cols
# Out:
# ['pca_0', 'pca_1']

# %%
def get_pd_from_pca(pca_data, col_num):
    cols = ['pca_'+str(n) for n in range(col_num)]
    return pd.DataFrame(pca_data, columns=cols)

# %%
HAR_pca, pca = get_pca_data(X_train, n_components=2)
HAR_pd_pca = get_pd_from_pca(HAR_pca, pca.components_.shape[0])
HAR_pd_pca['action'] = y_train
HAR_pd_pca.head()
# Out:
#       pca_0     pca_1  action
# 0 -5.520280 -0.290278       5
# 1 -5.535350 -0.082530       5
# 2 -5.474988  0.287387       5
# 3 -5.677232  0.897031       5
# 4 -5.748749  1.162952       5

# %%
import seaborn as sns

sns.pairplot(HAR_pd_pca, hue='action', height=5, x_vars=['pca_0'], y_vars=['pca_1']);

# %%
import numpy as np

def print_variance_ratio(pca):
    print('variance_ratio: ', pca. explained_variance_ratio_)
    print('sum of variance_ratio: ', np.sum(pca.explained_variance_ratio_))

print_variance_ratio(pca)
# Out:
# variance_ratio:  [0.6255444  0.04913023]
# sum of variance_ratio:  0.6746746270487957

# %%
HAR_pca, pca = get_pca_data(X_train, n_components=10)
HAR_pd_pca = get_pd_from_pca(HAR_pca, pca.components_.shape[0])
HAR_pd_pca['action'] = y_train

print_variance_ratio(pca)
# Out:
# variance_ratio:  [0.6255444  0.04913023 0.04121467 0.01874956 0.0169486  0.01272069
#  0.01176685 0.01068973 0.00969376 0.00858016]
# sum of variance_ratio:  0.805038656222749

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier

params = {
    'max_depth' : [6, 8, 10],
    'n_estimators' : [50, 100, 200],
    'min_samples_leaf' : [8, 12],
    'min_samples_split' : [8, 12]
}

rf_clf = RandomForestClassifier(random_state=13, n_jobs=-1)
grid_cv = GridSearchCV(rf_clf, param_grid=params, cv=2, n_jobs=-1)
grid_cv.fit(HAR_pca, y_train.values.reshape(-1,))
# Out:
# GridSearchCV(cv=2, estimator=RandomForestClassifier(n_jobs=-1, random_state=13),
#              n_jobs=-1,
#              param_grid={'max_depth': [6, 8, 10], 'min_samples_leaf': [8, 12],
#                          'min_samples_split': [8, 12],
#                          'n_estimators': [50, 100, 200]})

# %%
cv_results_df = pd.DataFrame(grid_cv.cv_results_)
target_col = ['rank_test_score', 'mean_test_score', 'param_n_estimators', 'param_max_depth']
cv_results_df[target_col].sort_values('rank_test_score').head()
# Out:
#     rank_test_score  mean_test_score param_n_estimators param_max_depth
# 17                1         0.838819                200               8
# 14                1         0.838819                200               8
# 32                3         0.837867                200              10
# 35                3         0.837867                200              10
# 26                5         0.837595                200              10

# %%
grid_cv.best_params_
# Out:
# {'max_depth': 8,
#  'min_samples_leaf': 8,
#  'min_samples_split': 8,
#  'n_estimators': 200}

# %%
grid_cv.best_score_
# Out:
# 0.8388193688792165

# %%
from sklearn.metrics import accuracy_score

rf_clf_best = grid_cv.best_estimator_
rf_clf_best.fit(HAR_pca, y_train.values.reshape(-1,))

pred1 = rf_clf_best.predict(pca.transform(X_test))

accuracy_score(y_test, pred1)
# Out:
# 0.8540889039701391

# %%
import numpy as np
import time
from xgboost import XGBClassifier

# 클래스 레이블을 0부터 시작하도록 조정
y_train_adjusted = y_train - 1
y_test_adjusted = y_test - 1

# 평가 데이터셋도 조정
evals = [(pca.transform(X_test), y_test_adjusted)]

# 모델 학습 시작 시간
start_time = time.time()

# XGBClassifier 모델 생성 및 학습
xgb = XGBClassifier(n_estimators=400, learning_rate=0.1, max_depth=3)
xgb.fit(HAR_pca, y_train_adjusted.values.reshape(-1,), early_stopping_rounds=10, eval_set=evals)

# 학습 시간 출력
print('Fit time : ', time.time() - start_time)
# Out:
# [0]	validation_0-mlogloss:1.61500
# /home/verlo/venv/OpenCV_venv/lib/python3.10/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [1]	validation_0-mlogloss:1.47654
# [2]	validation_0-mlogloss:1.35917
# [3]	validation_0-mlogloss:1.26405
# [4]	validation_0-mlogloss:1.18121
# [5]	validation_0-mlogloss:1.11070
# [6]	validation_0-mlogloss:1.04662
# [7]	validation_0-mlogloss:0.98965
# [8]	validation_0-mlogloss:0.93990
# [9]	validation_0-mlogloss:0.89277
# [10]	validation_0-mlogloss:0.85221
# [11]	validation_0-mlogloss:0.81596
# [12]	validation_0-mlogloss:0.78359
# [13]	validation_0-mlogloss:0.75357
# [14]	validation_0-mlogloss:0.72590
# [15]	validation_0-mlogloss:0.70094
# [16]	validation_0-mlogloss:0.67926
# [17]	validation_0-mlogloss:0.65833
# [18]	validation_0-mlogloss:0.63910
# [19]	validation_0-mlogloss:0.62196
# [20]	validation_0-mlogloss:0.60465
# [21]	validation_0-mlogloss:0.58927
# [22]	validation_0-mlogloss:0.57543
# [23]	validation_0-mlogloss:0.56239
# [24]	validation_0-mlogloss:0.54971
# [25]	validation_0-mlogloss:0.53854
# [26]	validation_0-mlogloss:0.52805
# [27]	validation_0-mlogloss:0.51898
# [28]	validation_0-mlogloss:0.50900
# [29]	validation_0-mlogloss:0.50027
# [30]	validation_0-mlogloss:0.49233
# [31]	validation_0-mlogloss:0.48561
# [32]	validation_0-mlogloss:0.47801
# [33]	validation_0-mlogloss:0.47127
# [34]	validation_0-mlogloss:0.46399
# [35]	validation_0-mlogloss:0.45816
# [36]	validation_0-mlogloss:0.45257
# [37]	validation_0-mlogloss:0.44735
# [38]	validation_0-mlogloss:0.44142
# [39]	validation_0-mlogloss:0.43747
# [40]	validation_0-mlogloss:0.43225
# [41]	validation_0-mlogloss:0.42789
# [42]	validation_0-mlogloss:0.42373
# [43]	validation_0-mlogloss:0.41985
# [44]	validation_0-mlogloss:0.41546
# [45]	validation_0-mlogloss:0.41196
# [46]	validation_0-mlogloss:0.40745
# [47]	validation_0-mlogloss:0.40412
# [48]	validation_0-mlogloss:0.40106
# [49]	validation_0-mlogloss:0.39792
# [50]	validation_0-mlogloss:0.39502
# [51]	validation_0-mlogloss:0.39245
# [52]	validation_0-mlogloss:0.39035
# [53]	validation_0-mlogloss:0.38771
# [54]	validation_0-mlogloss:0.38474
# [55]	validation_0-mlogloss:0.38298
# [56]	validation_0-mlogloss:0.38038
# [57]	validation_0-mlogloss:0.37840
# [58]	validation_0-mlogloss:0.37606
# [59]	validation_0-mlogloss:0.37341
# [60]	validation_0-mlogloss:0.37228
# [61]	validation_0-mlogloss:0.37044
# [62]	validation_0-mlogloss:0.36846
# [63]	validation_0-mlogloss:0.36699
# [64]	validation_0-mlogloss:0.36510
# [65]	validation_0-mlogloss:0.36378
# [66]	validation_0-mlogloss:0.36229
# [67]	validation_0-mlogloss:0.36068
# [68]	validation_0-mlogloss:0.35943
# [69]	validation_0-mlogloss:0.35809
# [70]	validation_0-mlogloss:0.35632
# [71]	validation_0-mlogloss:0.35550
# [72]	validation_0-mlogloss:0.35394
# [73]	validation_0-mlogloss:0.35286
# [74]	validation_0-mlogloss:0.35177
# [75]	validation_0-mlogloss:0.35070
# [76]	validation_0-mlogloss:0.34963
# [77]	validation_0-mlogloss:0.34895
# [78]	validation_0-mlogloss:0.34813
# [79]	validation_0-mlogloss:0.34704
# [80]	validation_0-mlogloss:0.34602
# [81]	validation_0-mlogloss:0.34479
# [82]	validation_0-mlogloss:0.34423
# [83]	validation_0-mlogloss:0.34361
# [84]	validation_0-mlogloss:0.34283
# [85]	validation_0-mlogloss:0.34185
# [86]	validation_0-mlogloss:0.34140
# [87]	validation_0-mlogloss:0.34070
# [88]	validation_0-mlogloss:0.34009
# [89]	validation_0-mlogloss:0.33895
# [90]	validation_0-mlogloss:0.33824
# [91]	validation_0-mlogloss:0.33808
# [92]	validation_0-mlogloss:0.33761
# [93]	validation_0-mlogloss:0.33692
# [94]	validation_0-mlogloss:0.33652
# [95]	validation_0-mlogloss:0.33602
# [96]	validation_0-mlogloss:0.33546
# [97]	validation_0-mlogloss:0.33558
# [98]	validation_0-mlogloss:0.33510
# [99]	validation_0-mlogloss:0.33489
# [100]	validation_0-mlogloss:0.33450
# [101]	validation_0-mlogloss:0.33430
# [102]	validation_0-mlogloss:0.33376
# [103]	validation_0-mlogloss:0.33376
# [104]	validation_0-mlogloss:0.33366
# [105]	validation_0-mlogloss:0.33358
# [106]	validation_0-mlogloss:0.33287
# [107]	validation_0-mlogloss:0.33237
# [108]	validation_0-mlogloss:0.33225
# [109]	validation_0-mlogloss:0.33176
# [110]	validation_0-mlogloss:0.33154
# [111]	validation_0-mlogloss:0.33155
# [112]	validation_0-mlogloss:0.33075
# [113]	validation_0-mlogloss:0.33050
# [114]	validation_0-mlogloss:0.33054
# [115]	validation_0-mlogloss:0.32993
# [116]	validation_0-mlogloss:0.32948
# [117]	validation_0-mlogloss:0.32943
# [118]	validation_0-mlogloss:0.32946
# [119]	validation_0-mlogloss:0.32960
# [120]	validation_0-mlogloss:0.32899
# [121]	validation_0-mlogloss:0.32916
# [122]	validation_0-mlogloss:0.32920
# [123]	validation_0-mlogloss:0.32940
# [124]	validation_0-mlogloss:0.32866
# [125]	validation_0-mlogloss:0.32883
# [126]	validation_0-mlogloss:0.32841
# [127]	validation_0-mlogloss:0.32812
# [128]	validation_0-mlogloss:0.32755
# [129]	validation_0-mlogloss:0.32702
# [130]	validation_0-mlogloss:0.32715
# [131]	validation_0-mlogloss:0.32699
# [132]	validation_0-mlogloss:0.32749
# [133]	validation_0-mlogloss:0.32736
# [134]	validation_0-mlogloss:0.32771
# [135]	validation_0-mlogloss:0.32819
# [136]	validation_0-mlogloss:0.32807
# [137]	validation_0-mlogloss:0.32741
# [138]	validation_0-mlogloss:0.32782
# [139]	validation_0-mlogloss:0.32711
# [140]	validation_0-mlogloss:0.32686
# [141]	validation_0-mlogloss:0.32693
# [142]	validation_0-mlogloss:0.32692
# [143]	validation_0-mlogloss:0.32659
# [144]	validation_0-mlogloss:0.32644
# [145]	validation_0-mlogloss:0.32546
# [146]	validation_0-mlogloss:0.32582
# [147]	validation_0-mlogloss:0.32556
# [148]	validation_0-mlogloss:0.32570
# [149]	validation_0-mlogloss:0.32556
# [150]	validation_0-mlogloss:0.32585
# [151]	validation_0-mlogloss:0.32585
# [152]	validation_0-mlogloss:0.32578
# [153]	validation_0-mlogloss:0.32607
# [154]	validation_0-mlogloss:0.32625
# [155]	validation_0-mlogloss:0.32634
# Fit time :  2.114835023880005

# %%
import time
from xgboost import XGBClassifier

evals = [(pca.transform(X_test), y_test)]

start_time = time.time()
xgb = XGBClassifier(n_estimators=400, learning_rate=0.1, max_depth=3)
xgb.fit(HAR_pca, y_train.values.reshape(-1,), early_stopping_rounds=10, eval_set=evals)

print('Fit time : ', time.time() - start_time)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 8
#       6 start_time = time.time()
#       7 xgb = XGBClassifier(n_estimators=400, learning_rate=0.1, max_depth=3)
# ----> 8 xgb.fit(HAR_pca, y_train.values.reshape(-1,), early_stopping_rounds=10, eval_set=evals)
#      10 print('Fit time : ', time.time() - start_time)
#
# File ~/venv/OpenCV_venv/lib/python3.10/site-packages/xgboost/core.py:730, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     728 for k, arg in zip(sig.parameters, args):
#     729     kwargs[k] = arg
# --> 730 return func(**kwargs)
#
# File ~/venv/OpenCV_venv/lib/python3.10/site-packages/xgboost/sklearn.py:1471, in XGBClassifier.fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#    1466     expected_classes = self.classes_
#    1467 if (
#    1468     classes.shape != expected_classes.shape
#    1469     or not (classes == expected_classes).all()
#    1470 ):
# -> 1471     raise ValueError(
#    1472         f"Invalid classes inferred from unique values of `y`.  "
#    1473         f"Expected: {expected_classes}, got {classes}"
#    1474     )
#    1476 params = self.get_xgb_params()
#    1478 if callable(self.objective):
#
# ValueError: Invalid classes inferred from unique values of `y`.  Expected: [0 1 2 3 4 5], got [1 2 3 4 5 6]

# %%
accuracy_score(y_test, xgb.predict(pca.transform(X_test)))
# Out:
# 0.05972175093315236
