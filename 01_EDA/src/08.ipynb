# %%
import numpy as np
import pandas as pd

# %%
crime_raw_data = pd.read_csv("../data/2016년.csv", encoding="euc-kr")
crime_raw_data.head()
# Out:
#    구분  죄종 발생검거     건수
# 0  중부  살인   발생    2.0
# 1  중부  살인   검거    2.0
# 2  중부  강도   발생    3.0
# 3  중부  강도   검거    3.0
# 4  중부  강간   발생  141.0

# %%
crime_raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65534 entries, 0 to 65533
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   구분      310 non-null    object
#  1   죄종      310 non-null    object
#  2   발생검거    310 non-null    object
#  3   건수      310 non-null    float64
# dtypes: float64(1), object(3)
# memory usage: 2.0+ MB

# %%
crime_raw_data["죄종"].unique()
# Out:
# array(['살인', '강도', '강간', '절도', '폭력', nan], dtype=object)

# %%
crime_raw_data[crime_raw_data["죄종"].isnull()]
# Out:
#         구분   죄종 발생검거  건수
# 310    NaN  NaN  NaN NaN
# 311    NaN  NaN  NaN NaN
# 312    NaN  NaN  NaN NaN
# 313    NaN  NaN  NaN NaN
# 314    NaN  NaN  NaN NaN
# ...    ...  ...  ...  ..
# 65529  NaN  NaN  NaN NaN
# 65530  NaN  NaN  NaN NaN
# 65531  NaN  NaN  NaN NaN
# 65532  NaN  NaN  NaN NaN
# 65533  NaN  NaN  NaN NaN
#
# [65224 rows x 4 columns]

# %%
crime_raw_data = crime_raw_data[crime_raw_data["죄종"].notnull()]
crime_raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 310 entries, 0 to 309
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   구분      310 non-null    object
#  1   죄종      310 non-null    object
#  2   발생검거    310 non-null    object
#  3   건수      310 non-null    float64
# dtypes: float64(1), object(3)
# memory usage: 12.1+ KB

# %%
crime_raw_data
# Out:
#      구분  죄종 발생검거      건수
# 0    중부  살인   발생     2.0
# 1    중부  살인   검거     2.0
# 2    중부  강도   발생     3.0
# 3    중부  강도   검거     3.0
# 4    중부  강간   발생   141.0
# ..   ..  ..  ...     ...
# 305  수서  강간   검거   144.0
# 306  수서  절도   발생  1149.0
# 307  수서  절도   검거   789.0
# 308  수서  폭력   발생  1666.0
# 309  수서  폭력   검거  1431.0
#
# [310 rows x 4 columns]

# %%
df = pd.read_excel("../data/sales-funnel.xlsx")
df.head()
# Out:
#    Account                          Name            Rep       Manager  \
# 0   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 1   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 2   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 3   737550  Fritsch, Russel and Anderson   Craig Booker  Debra Henley
# 4   146832                  Kiehn-Spinka  Daniel Hilton  Debra Henley
#
#        Product  Quantity  Price     Status
# 0          CPU         1  30000  presented
# 1     Software         1  10000  presented
# 2  Maintenance         2   5000    pending
# 3          CPU         1  35000   declined
# 4          CPU         2  65000        won

# %%
pd.pivot_table(data=df, index="Name", values="Account")
# Out:
#                                Account
# Name
# Barton LLC                    740150.0
# Fritsch, Russel and Anderson  737550.0
# Herman LLC                    141962.0
# Jerde-Hilpert                 412290.0
# Kassulke, Ondricka and Metz   307599.0
# Keeling LLC                   688981.0
# Kiehn-Spinka                  146832.0
# Koepp Ltd                     729833.0
# Kulas Inc                     218895.0
# Purdy-Kunde                   163416.0
# Stokes LLC                    239344.0
# Trantow-Barrows               714466.0

# %%
pd.pivot_table(data=df, index="Name", values=["Account", "Price", "Quantity"])
# Out:
#                                Account     Price  Quantity
# Name
# Barton LLC                    740150.0   35000.0  1.000000
# Fritsch, Russel and Anderson  737550.0   35000.0  1.000000
# Herman LLC                    141962.0   65000.0  2.000000
# Jerde-Hilpert                 412290.0    5000.0  2.000000
# Kassulke, Ondricka and Metz   307599.0    7000.0  3.000000
# Keeling LLC                   688981.0  100000.0  5.000000
# Kiehn-Spinka                  146832.0   65000.0  2.000000
# Koepp Ltd                     729833.0   35000.0  2.000000
# Kulas Inc                     218895.0   25000.0  1.500000
# Purdy-Kunde                   163416.0   30000.0  1.000000
# Stokes LLC                    239344.0    7500.0  1.000000
# Trantow-Barrows               714466.0   15000.0  1.333333

# %%
pd.pivot_table(data=df, index=["Name", "Rep", 'Manager'], values=["Account", "Price", "Quantity"])
# Out:
#                                                            Account     Price  \
# Name                         Rep           Manager
# Barton LLC                   John Smith    Debra Henley   740150.0   35000.0
# Fritsch, Russel and Anderson Craig Booker  Debra Henley   737550.0   35000.0
# Herman LLC                   Cedric Moss   Fred Anderson  141962.0   65000.0
# Jerde-Hilpert                John Smith    Debra Henley   412290.0    5000.0
# Kassulke, Ondricka and Metz  Wendy Yule    Fred Anderson  307599.0    7000.0
# Keeling LLC                  Wendy Yule    Fred Anderson  688981.0  100000.0
# Kiehn-Spinka                 Daniel Hilton Debra Henley   146832.0   65000.0
# Koepp Ltd                    Wendy Yule    Fred Anderson  729833.0   35000.0
# Kulas Inc                    Daniel Hilton Debra Henley   218895.0   25000.0
# Purdy-Kunde                  Cedric Moss   Fred Anderson  163416.0   30000.0
# Stokes LLC                   Cedric Moss   Fred Anderson  239344.0    7500.0
# Trantow-Barrows              Craig Booker  Debra Henley   714466.0   15000.0
#
#                                                           Quantity
# Name                         Rep           Manager
# Barton LLC                   John Smith    Debra Henley   1.000000
# Fritsch, Russel and Anderson Craig Booker  Debra Henley   1.000000
# Herman LLC                   Cedric Moss   Fred Anderson  2.000000
# Jerde-Hilpert                John Smith    Debra Henley   2.000000
# Kassulke, Ondricka and Metz  Wendy Yule    Fred Anderson  3.000000
# Keeling LLC                  Wendy Yule    Fred Anderson  5.000000
# Kiehn-Spinka                 Daniel Hilton Debra Henley   2.000000
# Koepp Ltd                    Wendy Yule    Fred Anderson  2.000000
# Kulas Inc                    Daniel Hilton Debra Henley   1.500000
# Purdy-Kunde                  Cedric Moss   Fred Anderson  1.000000
# Stokes LLC                   Cedric Moss   Fred Anderson  1.000000
# Trantow-Barrows              Craig Booker  Debra Henley   1.333333

# %%
pd.pivot_table(data=df, index=["Name", "Rep"], values="Price", aggfunc=np.sum)
# Out:
# /tmp/ipykernel_11024/4064892098.py:1: FutureWarning: The provided callable <function sum at 0x7f8e1809e320> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   pd.pivot_table(data=df, index=["Name", "Rep"], values="Price", aggfunc=np.sum)
#                                              Price
# Name                         Rep
# Barton LLC                   John Smith      35000
# Fritsch, Russel and Anderson Craig Booker    35000
# Herman LLC                   Cedric Moss     65000
# Jerde-Hilpert                John Smith       5000
# Kassulke, Ondricka and Metz  Wendy Yule       7000
# Keeling LLC                  Wendy Yule     100000
# Kiehn-Spinka                 Daniel Hilton   65000
# Koepp Ltd                    Wendy Yule      70000
# Kulas Inc                    Daniel Hilton   50000
# Purdy-Kunde                  Cedric Moss     30000
# Stokes LLC                   Cedric Moss     15000
# Trantow-Barrows              Craig Booker    45000

# %%
pd.pivot_table(data=df, index=["Manager", "Rep"], values="Price", columns="Product", aggfunc=np.sum)
# Out:
# /tmp/ipykernel_11024/1746399842.py:1: FutureWarning: The provided callable <function sum at 0x7f8e1809e320> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   pd.pivot_table(data=df, index=["Manager", "Rep"], values="Price", columns="Product", aggfunc=np.sum)
# Product                           CPU  Maintenance  Monitor  Software
# Manager       Rep
# Debra Henley  Craig Booker    65000.0       5000.0      NaN   10000.0
#               Daniel Hilton  105000.0          NaN      NaN   10000.0
#               John Smith      35000.0       5000.0      NaN       NaN
# Fred Anderson Cedric Moss     95000.0       5000.0      NaN   10000.0
#               Wendy Yule     165000.0       7000.0   5000.0       NaN

# %%
pd.pivot_table(data=df, index=["Manager", "Rep"], values="Price", columns="Product", aggfunc=np.sum, fill_value=0)
# Out:
# /tmp/ipykernel_11024/2289858843.py:1: FutureWarning: The provided callable <function sum at 0x7f8e1809e320> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   pd.pivot_table(data=df, index=["Manager", "Rep"], values="Price", columns="Product", aggfunc=np.sum, fill_value=0)
# Product                         CPU  Maintenance  Monitor  Software
# Manager       Rep
# Debra Henley  Craig Booker    65000         5000        0     10000
#               Daniel Hilton  105000            0        0     10000
#               John Smith      35000         5000        0         0
# Fred Anderson Cedric Moss     95000         5000        0     10000
#               Wendy Yule     165000         7000     5000         0

# %%
crime_station = crime_raw_data.pivot_table(index="구분", columns=["죄종", "발생검거"], aggfunc=np.sum)
# Out:
# /tmp/ipykernel_11024/1912494841.py:1: FutureWarning: The provided callable <function sum at 0x7f8e1809e320> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   crime_station = crime_raw_data.pivot_table(index="구분", columns=["죄종", "발생검거"], aggfunc=np.sum)

# %%
crime_station.head()
# Out:
#          건수
# 죄종       강간           강도          살인           절도              폭력
# 발생검거     검거     발생    검거    발생    검거   발생      검거      발생      검거      발생
# 구분
# 강남    269.0  339.0  26.0  24.0   3.0  3.0  1129.0  2438.0  2096.0  2336.0
# 강동    152.0  160.0  13.0  14.0   5.0  4.0   902.0  1754.0  2201.0  2530.0
# 강북    159.0  217.0   4.0   5.0   6.0  7.0   672.0  1222.0  2482.0  2778.0
# 강서    239.0  275.0  10.0  10.0  10.0  9.0  1070.0  1952.0  2768.0  3204.0
# 관악    264.0  322.0  10.0  12.0   7.0  6.0   937.0  2103.0  2707.0  3235.0

# %%
crime_station.columns
# Out:
# MultiIndex([('건수', '강간', '검거'),
#             ('건수', '강간', '발생'),
#             ('건수', '강도', '검거'),
#             ('건수', '강도', '발생'),
#             ('건수', '살인', '검거'),
#             ('건수', '살인', '발생'),
#             ('건수', '절도', '검거'),
#             ('건수', '절도', '발생'),
#             ('건수', '폭력', '검거'),
#             ('건수', '폭력', '발생')],
#            names=[None, '죄종', '발생검거'])

# %%
crime_station.columns = crime_station.columns.droplevel([0])
crime_station.columns
# Out:
# MultiIndex([('강간', '검거'),
#             ('강간', '발생'),
#             ('강도', '검거'),
#             ('강도', '발생'),
#             ('살인', '검거'),
#             ('살인', '발생'),
#             ('절도', '검거'),
#             ('절도', '발생'),
#             ('폭력', '검거'),
#             ('폭력', '발생')],
#            names=['죄종', '발생검거'])

# %%
crime_station["강간", "검거"].head()
# Out:
# 구분
# 강남    269.0
# 강동    152.0
# 강북    159.0
# 강서    239.0
# 관악    264.0
# Name: (강간, 검거), dtype: float64

# %%
crime_station["살인", "발생"].head()
# Out:
# 구분
# 강남    3.0
# 강동    4.0
# 강북    7.0
# 강서    9.0
# 관악    6.0
# Name: (살인, 발생), dtype: float64

# %%
crime_station.loc["강남", ("강도", "발생")]
# Out:
# 24.0

# %%
crime_station.head()
# Out:
# 죄종       강간           강도          살인           절도              폭력
# 발생검거     검거     발생    검거    발생    검거   발생      검거      발생      검거      발생
# 구분
# 강남    269.0  339.0  26.0  24.0   3.0  3.0  1129.0  2438.0  2096.0  2336.0
# 강동    152.0  160.0  13.0  14.0   5.0  4.0   902.0  1754.0  2201.0  2530.0
# 강북    159.0  217.0   4.0   5.0   6.0  7.0   672.0  1222.0  2482.0  2778.0
# 강서    239.0  275.0  10.0  10.0  10.0  9.0  1070.0  1952.0  2768.0  3204.0
# 관악    264.0  322.0  10.0  12.0   7.0  6.0   937.0  2103.0  2707.0  3235.0

# %%
tmp = crime_station.columns.get_level_values(0) + crime_station.columns.get_level_values(1)
tmp
# Out:
# Index(['강간검거', '강간발생', '강도검거', '강도발생', '살인검거', '살인발생', '절도검거', '절도발생', '폭력검거',
#        '폭력발생'],
#       dtype='object')

# %%
crime_station.columns = tmp
crime_station.head()
# Out:
#      강간검거   강간발생  강도검거  강도발생  살인검거  살인발생    절도검거    절도발생    폭력검거    폭력발생
# 구분
# 강남  269.0  339.0  26.0  24.0   3.0   3.0  1129.0  2438.0  2096.0  2336.0
# 강동  152.0  160.0  13.0  14.0   5.0   4.0   902.0  1754.0  2201.0  2530.0
# 강북  159.0  217.0   4.0   5.0   6.0   7.0   672.0  1222.0  2482.0  2778.0
# 강서  239.0  275.0  10.0  10.0  10.0   9.0  1070.0  1952.0  2768.0  3204.0
# 관악  264.0  322.0  10.0  12.0   7.0   6.0   937.0  2103.0  2707.0  3235.0

# %%
crime_station.rename(columns={"강간검거": "성범죄검거", "강간발생": "성범죄발생"}, inplace=True)

# %%
crime_station.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31 entries, 강남 to 혜화
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   성범죄검거   31 non-null     float64
#  1   성범죄발생   31 non-null     float64
#  2   강도검거    31 non-null     float64
#  3   강도발생    31 non-null     float64
#  4   살인검거    31 non-null     float64
#  5   살인발생    31 non-null     float64
#  6   절도검거    31 non-null     float64
#  7   절도발생    31 non-null     float64
#  8   폭력검거    31 non-null     float64
#  9   폭력발생    31 non-null     float64
# dtypes: float64(10)
# memory usage: 3.7+ KB

# %%
dict_sample = {"Name": "Zara", "Age": 7, "Class": "First"}

# %%
dict_sample.keys()
# Out:
# dict_keys(['Name', 'Age', 'Class'])

# %%
dict_sample["Name"]
# Out:
# 'Zara'

# %%
dict_sample["Age"]
# Out:
# 7

# %%
dict_sample.items()
# Out:
# dict_items([('Name', 'Zara'), ('Age', 7), ('Class', 'First')])

# %%
for key, value in dict_sample.items():
    print(key, value)
# Out:
# Name Zara
# Age 7
# Class First

# %%
crime_station.head()
# Out:
#     성범죄검거  성범죄발생  강도검거  강도발생  살인검거  살인발생    절도검거    절도발생    폭력검거    폭력발생
# 구분
# 강남  269.0  339.0  26.0  24.0   3.0   3.0  1129.0  2438.0  2096.0  2336.0
# 강동  152.0  160.0  13.0  14.0   5.0   4.0   902.0  1754.0  2201.0  2530.0
# 강북  159.0  217.0   4.0   5.0   6.0   7.0   672.0  1222.0  2482.0  2778.0
# 강서  239.0  275.0  10.0  10.0  10.0   9.0  1070.0  1952.0  2768.0  3204.0
# 관악  264.0  322.0  10.0  12.0   7.0   6.0   937.0  2103.0  2707.0  3235.0

# %%
real_gu = {'종로구': ['종로', '혜화'], '중구': ['남대문', '중부'],
           '용산구': ['용산'], '성동구': ['성동'],
           '광진구': ['광진'], '동대문구': ['동대문'],
           '중랑구': ['중랑'], '성북구': ['성북', '종암'],
           '강북구': ['강북'], '도봉구': ['도봉'],
           '노원구': ['노원'], '은평구': ['서부', '은평'],
           '서대문구': ['서대문'], '마포구': ['마포'],
           '양천구': ['양천'], '강서구': ['강서'],
           '구로구': ['구로'], '금천구': ['금천'],
           '영등포구': ['영등포'], '동작구': ['동작'],
           '관악구': ['관악'], '서초구': ['방배', '서초'],
           '강남구': ['강남', '수서'], '송파구': ['송파'],
           '강동구': ['강동']}

# %%
real_gu.items()
# Out:
# dict_items([('종로구', ['종로', '혜화']), ('중구', ['남대문', '중부']), ('용산구', ['용산']), ('성동구', ['성동']), ('광진구', ['광진']), ('동대문구', ['동대문']), ('중랑구', ['중랑']), ('성북구', ['성북', '종암']), ('강북구', ['강북']), ('도봉구', ['도봉']), ('노원구', ['노원']), ('은평구', ['서부', '은평']), ('서대문구', ['서대문']), ('마포구', ['마포']), ('양천구', ['양천']), ('강서구', ['강서']), ('구로구', ['구로']), ('금천구', ['금천']), ('영등포구', ['영등포']), ('동작구', ['동작']), ('관악구', ['관악']), ('서초구', ['방배', '서초']), ('강남구', ['강남', '수서']), ('송파구', ['송파']), ('강동구', ['강동'])])

# %%
real_gu["서초구"]
# Out:
# ['방배', '서초']

# %%
real_gu["강남구"]
# Out:
# ['강남', '수서']

# %%
for gu_name, station_name in real_gu.items():
    if "강남" in station_name:
        print(gu_name)
# Out:
# 강남구

# %%
tmp_gu = []
for station in crime_station.index:
    for gu_name, station_name in real_gu.items():
        if station in station_name:
            tmp_gu.append(gu_name)

# %%
['강남구',
 '강동구',
 '강북구',
 '강서구',
 '관악구',
 '광진구',
 '구로구',
 '금천구',
 '중구',]
# Out:
# ['강남구', '강동구', '강북구', '강서구', '관악구', '광진구', '구로구', '금천구', '중구']

# %%
crime_station['구'] = tmp_gu
crime_station.head()
# Out:
#     성범죄검거  성범죄발생  강도검거  강도발생  살인검거  살인발생    절도검거    절도발생    폭력검거    폭력발생    구
# 구분
# 강남  269.0  339.0  26.0  24.0   3.0   3.0  1129.0  2438.0  2096.0  2336.0  강남구
# 강동  152.0  160.0  13.0  14.0   5.0   4.0   902.0  1754.0  2201.0  2530.0  강동구
# 강북  159.0  217.0   4.0   5.0   6.0   7.0   672.0  1222.0  2482.0  2778.0  강북구
# 강서  239.0  275.0  10.0  10.0  10.0   9.0  1070.0  1952.0  2768.0  3204.0  강서구
# 관악  264.0  322.0  10.0  12.0   7.0   6.0   937.0  2103.0  2707.0  3235.0  관악구

# %%
crime_gu = crime_station.pivot_table(index="구", aggfunc=np.sum)
crime_gu.head()
# Out:
# /tmp/ipykernel_11024/397152675.py:1: FutureWarning: The provided callable <function sum at 0x7f8e1809e320> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   crime_gu = crime_station.pivot_table(index="구", aggfunc=np.sum)
#      강도검거  강도발생  살인검거  살인발생  성범죄검거  성범죄발생    절도검거    절도발생    폭력검거    폭력발생
# 구
# 강남구  42.0  39.0   5.0   5.0  413.0  516.0  1918.0  3587.0  3527.0  4002.0
# 강동구  13.0  14.0   5.0   4.0  152.0  160.0   902.0  1754.0  2201.0  2530.0
# 강북구   4.0   5.0   6.0   7.0  159.0  217.0   672.0  1222.0  2482.0  2778.0
# 강서구  10.0  10.0  10.0   9.0  239.0  275.0  1070.0  1952.0  2768.0  3204.0
# 관악구  10.0  12.0   7.0   6.0  264.0  322.0   937.0  2103.0  2707.0  3235.0

# %%
crime_gu["살인발생"].sort_values(ascending=False).head()
# Out:
# 구
# 영등포구    13.0
# 강서구      9.0
# 구로구      9.0
# 송파구      9.0
# 중랑구      8.0
# Name: 살인발생, dtype: float64

# %%
crime_gu["폭력발생"].sort_values(ascending=False).head()
# Out:
# 구
# 강남구     4002.0
# 영등포구    3593.0
# 송파구     3289.0
# 관악구     3235.0
# 강서구     3204.0
# Name: 폭력발생, dtype: float64

# %%
crime_gu["강도발생"].sort_values(ascending=False).head()
# Out:
# 구
# 강남구     39.0
# 영등포구    19.0
# 송파구     15.0
# 강동구     14.0
# 중랑구     14.0
# Name: 강도발생, dtype: float64

# %%
(crime_gu["절도검거"] / crime_gu["절도발생"]) * 100
# Out:
# 구
# 강남구     53.470867
# 강동구     51.425314
# 강북구     54.991817
# 강서구     54.815574
# 관악구     44.555397
# 광진구     40.098634
# 구로구     45.078534
# 금천구     51.740506
# 노원구     39.849219
# 도봉구     56.812933
# 동대문구    55.206186
# 동작구     45.187602
# 마포구     37.198259
# 서대문구    50.033267
# 서초구     50.204082
# 성동구     69.135802
# 성북구     49.319728
# 송파구     41.211168
# 양천구     43.920884
# 영등포구    40.153780
# 용산구     40.228341
# 은평구     53.421369
# 종로구     39.587629
# 중구      42.511628
# 중랑구     62.211709
# dtype: float64

# %%
arrest_col = ["강도검거", "살인검거", "성범죄검거", "절도검거", "폭력검거"]
occur_col = ["강도발생", "살인발생", "성범죄발생", "절도발생", "폭력발생"]

# %%
crime_gu[arrest_col].div(crime_gu[occur_col].values) * 100
# Out:
#             강도검거        살인검거      성범죄검거       절도검거       폭력검거
# 구
# 강남구   107.692308  100.000000  80.038760  53.470867  88.130935
# 강동구    92.857143  125.000000  95.000000  51.425314  86.996047
# 강북구    80.000000   85.714286  73.271889  54.991817  89.344852
# 강서구   100.000000  111.111111  86.909091  54.815574  86.392010
# 관악구    83.333333  116.666667  81.987578  44.555397  83.678516
# 광진구    54.545455  100.000000  83.870968  40.098634  84.071906
# 구로구   130.000000  100.000000  66.300366  45.078534  84.702908
# 금천구   100.000000  100.000000  81.714286  51.740506  88.736890
# 노원구   150.000000  120.000000  89.308176  39.849219  84.419714
# 도봉구   100.000000  100.000000  98.373984  56.812933  90.839695
# 동대문구  120.000000  100.000000  83.157895  55.206186  89.969720
# 동작구   100.000000   75.000000  45.846154  45.187602  86.935581
# 마포구   175.000000  100.000000  80.200501  37.198259  85.062947
# 서대문구   80.000000  116.666667  84.000000  50.033267  83.198381
# 서초구    76.923077  100.000000  63.317757  50.204082  86.783576
# 성동구   166.666667  125.000000  75.000000  69.135802  86.967264
# 성북구   100.000000   75.000000  75.974026  49.319728  86.290323
# 송파구    80.000000   88.888889  78.632479  41.211168  85.375494
# 양천구   100.000000  100.000000  82.442748  43.920884  85.244444
# 영등포구   73.684211  100.000000  63.202247  40.153780  83.690509
# 용산구   111.111111  100.000000  85.258964  40.228341  84.228188
# 은평구    77.777778  100.000000  91.025641  53.421369  86.636637
# 종로구    75.000000   33.333333  74.369748  39.587629  87.361909
# 중구     87.500000  100.000000  74.747475  42.511628  89.707865
# 중랑구   100.000000   87.500000  91.463415  62.211709  85.714286

# %%
arrest_rate = ["성범죄검거율", "강도검거율", "살인검거율", "절도검거율", "폭력검거율"]
crime_gu[arrest_rate] = crime_gu[arrest_col].div(crime_gu[occur_col].values) * 100

# %%
crime_gu.head()
# Out:
#      강도검거  강도발생  살인검거  살인발생  성범죄검거  성범죄발생    절도검거    절도발생    폭력검거    폭력발생  \
# 구
# 강남구  42.0  39.0   5.0   5.0  413.0  516.0  1918.0  3587.0  3527.0  4002.0
# 강동구  13.0  14.0   5.0   4.0  152.0  160.0   902.0  1754.0  2201.0  2530.0
# 강북구   4.0   5.0   6.0   7.0  159.0  217.0   672.0  1222.0  2482.0  2778.0
# 강서구  10.0  10.0  10.0   9.0  239.0  275.0  1070.0  1952.0  2768.0  3204.0
# 관악구  10.0  12.0   7.0   6.0  264.0  322.0   937.0  2103.0  2707.0  3235.0
#
#          성범죄검거율       강도검거율      살인검거율      절도검거율      폭력검거율
# 구
# 강남구  107.692308  100.000000  80.038760  53.470867  88.130935
# 강동구   92.857143  125.000000  95.000000  51.425314  86.996047
# 강북구   80.000000   85.714286  73.271889  54.991817  89.344852
# 강서구  100.000000  111.111111  86.909091  54.815574  86.392010
# 관악구   83.333333  116.666667  81.987578  44.555397  83.678516

# %%
crime_gu.loc["강남구", "강도검거"], crime_gu.loc["강남구", "강도발생"]
# Out:
# (42.0, 39.0)

# %%
(crime_gu.loc["강남구", "강도검거"] / crime_gu.loc["강남구", "강도발생"]) * 100
# Out:
# 107.6923076923077

# %%
crime_gu[crime_gu[arrest_rate] > 100] = 100
crime_gu.head(3)
# Out:
#      강도검거  강도발생  살인검거  살인발생  성범죄검거  성범죄발생    절도검거    절도발생    폭력검거    폭력발생  \
# 구
# 강남구  42.0  39.0   5.0   5.0  413.0  516.0  1918.0  3587.0  3527.0  4002.0
# 강동구  13.0  14.0   5.0   4.0  152.0  160.0   902.0  1754.0  2201.0  2530.0
# 강북구   4.0   5.0   6.0   7.0  159.0  217.0   672.0  1222.0  2482.0  2778.0
#
#          성범죄검거율       강도검거율      살인검거율      절도검거율      폭력검거율
# 구
# 강남구  100.000000  100.000000  80.038760  53.470867  88.130935
# 강동구   92.857143  100.000000  95.000000  51.425314  86.996047
# 강북구   80.000000   85.714286  73.271889  54.991817  89.344852

# %%
crime_gu.drop(columns=arrest_col, axis=1, inplace=True)

# %%
crime_gu.rename(columns={
    "강도발생": "강도", "살인발생": "살인", "성범죄발생": "성범죄",
    "절도발생": "절도", "폭력발생": "폭력"
}, inplace=True)

# %%
crime_gu.head()
# Out:
#        강도   살인    성범죄      절도      폭력      성범죄검거율       강도검거율      살인검거율  \
# 구
# 강남구  39.0  5.0  516.0  3587.0  4002.0  100.000000  100.000000  80.038760
# 강동구  14.0  4.0  160.0  1754.0  2530.0   92.857143  100.000000  95.000000
# 강북구   5.0  7.0  217.0  1222.0  2778.0   80.000000   85.714286  73.271889
# 강서구  10.0  9.0  275.0  1952.0  3204.0  100.000000  100.000000  86.909091
# 관악구  12.0  6.0  322.0  2103.0  3235.0   83.333333  100.000000  81.987578
#
#          절도검거율      폭력검거율
# 구
# 강남구  53.470867  88.130935
# 강동구  51.425314  86.996047
# 강북구  54.991817  89.344852
# 강서구  54.815574  86.392010
# 관악구  44.555397  83.678516

# %%
occur_col = ["강도", "살인", "성범죄", "절도", "폭력"]
occur_col
# Out:
# ['강도', '살인', '성범죄', '절도', '폭력']

# %%
print("강서구 절도 건수:", crime_gu.loc["강서구", "절도"])
print("강서구 절도 건수의 최댓값:", crime_gu["절도"].max())
# Out:
# 강서구 절도 건수: 1952.0
# 강서구 절도 건수의 최댓값: 3587.0

# %%
crime_gu_norm = crime_gu[occur_col] / crime_gu[occur_col].max()
crime_gu_norm.head()
# Out:
#            강도        살인       성범죄        절도        폭력
# 구
# 강남구  1.000000  0.384615  1.000000  1.000000  1.000000
# 강동구  0.358974  0.307692  0.310078  0.488988  0.632184
# 강북구  0.128205  0.538462  0.420543  0.340675  0.694153
# 강서구  0.256410  0.692308  0.532946  0.544187  0.800600
# 관악구  0.307692  0.461538  0.624031  0.586284  0.808346

# %%
crime_gu_norm[arrest_rate] = crime_gu[arrest_rate]
crime_gu_norm.head()
# Out:
#            강도        살인       성범죄        절도        폭력      성범죄검거율       강도검거율  \
# 구
# 강남구  1.000000  0.384615  1.000000  1.000000  1.000000  100.000000  100.000000
# 강동구  0.358974  0.307692  0.310078  0.488988  0.632184   92.857143  100.000000
# 강북구  0.128205  0.538462  0.420543  0.340675  0.694153   80.000000   85.714286
# 강서구  0.256410  0.692308  0.532946  0.544187  0.800600  100.000000  100.000000
# 관악구  0.307692  0.461538  0.624031  0.586284  0.808346   83.333333  100.000000
#
#          살인검거율      절도검거율      폭력검거율
# 구
# 강남구  80.038760  53.470867  88.130935
# 강동구  95.000000  51.425314  86.996047
# 강북구  73.271889  54.991817  89.344852
# 강서구  86.909091  54.815574  86.392010
# 관악구  81.987578  44.555397  83.678516

# %%
crime_gu_norm[occur_col].loc["강남구"]
# Out:
# 강도     1.000000
# 살인     0.384615
# 성범죄    1.000000
# 절도     1.000000
# 폭력     1.000000
# Name: 강남구, dtype: float64

# %%
crime_gu_norm[occur_col].loc["강남구"].sum()
# Out:
# 4.384615384615385

# %%
crime_gu_norm[occur_col].loc["강남구"].sum() / 5
# Out:
# 0.876923076923077

# %%
crime_gu_norm["범죄"] = np.mean(crime_gu_norm[occur_col], axis=1)

# %%
crime_gu_norm["검거"] = np.mean(crime_gu_norm[arrest_rate], axis=1)

# %%
crime_gu_norm["범죄"].sort_values(ascending=False).head()
# Out:
# 구
# 강남구     0.876923
# 영등포구    0.745508
# 송파구     0.612240
# 강서구     0.565290
# 구로구     0.560174
# Name: 범죄, dtype: float64

# %%
crime_gu_norm["검거"].sort_values(ascending=False).head()
# Out:
# 구
# 도봉구     89.205322
# 성동구     86.220613
# 동대문구    85.666760
# 강서구     85.623335
# 중랑구     85.377882
# Name: 검거, dtype: float64

# %%
crime_gu_norm["검거"].sort_values(ascending=True).head()
# Out:
# 구
# 종로구     61.930524
# 동작구     70.593867
# 영등포구    72.146149
# 광진구     72.517393
# 송파구     74.821606
# Name: 검거, dtype: float64

# %%
import matplotlib.pyplot as plt
import koreanize_matplotlib
import seaborn as sns

# %%
crime_gu_norm_sort = crime_gu_norm.sort_values(by="검거", ascending=False)
crime_gu_norm_sort.head()
# Out:
#             강도        살인       성범죄        절도        폭력  성범죄검거율  강도검거율  \
# 구
# 도봉구   0.128205  0.230769  0.238372  0.241427  0.360070   100.0  100.0
# 성동구   0.076923  0.307692  0.201550  0.361305  0.404548   100.0  100.0
# 동대문구  0.256410  0.384615  0.368217  0.540842  0.660170   100.0  100.0
# 강서구   0.256410  0.692308  0.532946  0.544187  0.800600   100.0  100.0
# 중랑구   0.358974  0.615385  0.317829  0.471425  0.790605   100.0   87.5
#
#           살인검거율      절도검거율      폭력검거율        범죄         검거
# 구
# 도봉구   98.373984  56.812933  90.839695  0.239769  89.205322
# 성동구   75.000000  69.135802  86.967264  0.270404  86.220613
# 동대문구  83.157895  55.206186  89.969720  0.442051  85.666760
# 강서구   86.909091  54.815574  86.392010  0.565290  85.623335
# 중랑구   91.463415  62.211709  85.714286  0.510844  85.377882

# %%
target_col = ["성범죄검거율", "강도검거율", "살인검거율", "절도검거율", "폭력검거율", "검거"]

plt.figure(figsize=(10, 10))
sns.heatmap(crime_gu_norm_sort[target_col], annot=True, fmt='f', linewidths=.5, cmap='RdPu')
plt.title("범죄 검거 비율")
plt.show();

# %%
target_col = ["성범죄", "강도", "살인", "절도", "폭력", "범죄"]
crime_gu_norm_sort = crime_gu_norm.sort_values(by="범죄", ascending=False)

plt.figure(figsize=(10, 10))
sns.heatmap(crime_gu_norm_sort[target_col], annot=True, fmt='f', linewidths=.5, cmap='RdPu')
plt.title("범죄 검거 비율")
plt.show();

# %%
crime_gu_norm.to_csv("../data/seoul_crime_result.csv", sep=",", encoding="utf-8")
