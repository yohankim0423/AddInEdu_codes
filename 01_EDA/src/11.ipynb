# %%
from glob import glob

# %%
target_path = '/home/verlo/dev_ws/EDA/data/number1'
file_list = glob(target_path+'/20*.csv')
file_list
# Out:
# ['/home/verlo/dev_ws/EDA/data/number1/2010.csv',
#  '/home/verlo/dev_ws/EDA/data/number1/2013.csv',
#  '/home/verlo/dev_ws/EDA/data/number1/2012.csv',
#  '/home/verlo/dev_ws/EDA/data/number1/2006.csv',
#  '/home/verlo/dev_ws/EDA/data/number1/2004.csv',
#  '/home/verlo/dev_ws/EDA/data/number1/2007.csv',
#  '/home/verlo/dev_ws/EDA/data/number1/2003.csv',
#  '/home/verlo/dev_ws/EDA/data/number1/2005.csv',
#  '/home/verlo/dev_ws/EDA/data/number1/2017.csv',
#  '/home/verlo/dev_ws/EDA/data/number1/2001.csv',
#  '/home/verlo/dev_ws/EDA/data/number1/2008.csv',
#  '/home/verlo/dev_ws/EDA/data/number1/2015.csv',
#  '/home/verlo/dev_ws/EDA/data/number1/2011.csv',
#  '/home/verlo/dev_ws/EDA/data/number1/2018.csv',
#  '/home/verlo/dev_ws/EDA/data/number1/2016.csv',
#  '/home/verlo/dev_ws/EDA/data/number1/2000.csv',
#  '/home/verlo/dev_ws/EDA/data/number1/2009.csv',
#  '/home/verlo/dev_ws/EDA/data/number1/2014.csv',
#  '/home/verlo/dev_ws/EDA/data/number1/2002.csv']

# %%
for each_file in file_list:
    print(each_file)
# Out:
# /home/verlo/dev_ws/EDA/data/number1/2010.csv
# /home/verlo/dev_ws/EDA/data/number1/2013.csv
# /home/verlo/dev_ws/EDA/data/number1/2012.csv
# /home/verlo/dev_ws/EDA/data/number1/2006.csv
# /home/verlo/dev_ws/EDA/data/number1/2004.csv
# /home/verlo/dev_ws/EDA/data/number1/2007.csv
# /home/verlo/dev_ws/EDA/data/number1/2003.csv
# /home/verlo/dev_ws/EDA/data/number1/2005.csv
# /home/verlo/dev_ws/EDA/data/number1/2017.csv
# /home/verlo/dev_ws/EDA/data/number1/2001.csv
# /home/verlo/dev_ws/EDA/data/number1/2008.csv
# /home/verlo/dev_ws/EDA/data/number1/2015.csv
# /home/verlo/dev_ws/EDA/data/number1/2011.csv
# /home/verlo/dev_ws/EDA/data/number1/2018.csv
# /home/verlo/dev_ws/EDA/data/number1/2016.csv
# /home/verlo/dev_ws/EDA/data/number1/2000.csv
# /home/verlo/dev_ws/EDA/data/number1/2009.csv
# /home/verlo/dev_ws/EDA/data/number1/2014.csv
# /home/verlo/dev_ws/EDA/data/number1/2002.csv

# %%
file_list
# Out:
# ['/home/verlo/dev_ws/EDA/data/number1/2010.csv',
#  '/home/verlo/dev_ws/EDA/data/number1/2013.csv',
#  '/home/verlo/dev_ws/EDA/data/number1/2012.csv',
#  '/home/verlo/dev_ws/EDA/data/number1/2006.csv',
#  '/home/verlo/dev_ws/EDA/data/number1/2004.csv',
#  '/home/verlo/dev_ws/EDA/data/number1/2007.csv',
#  '/home/verlo/dev_ws/EDA/data/number1/2003.csv',
#  '/home/verlo/dev_ws/EDA/data/number1/2005.csv',
#  '/home/verlo/dev_ws/EDA/data/number1/2017.csv',
#  '/home/verlo/dev_ws/EDA/data/number1/2001.csv',
#  '/home/verlo/dev_ws/EDA/data/number1/2008.csv',
#  '/home/verlo/dev_ws/EDA/data/number1/2015.csv',
#  '/home/verlo/dev_ws/EDA/data/number1/2011.csv',
#  '/home/verlo/dev_ws/EDA/data/number1/2018.csv',
#  '/home/verlo/dev_ws/EDA/data/number1/2016.csv',
#  '/home/verlo/dev_ws/EDA/data/number1/2000.csv',
#  '/home/verlo/dev_ws/EDA/data/number1/2009.csv',
#  '/home/verlo/dev_ws/EDA/data/number1/2014.csv',
#  '/home/verlo/dev_ws/EDA/data/number1/2002.csv']

# %%
import pandas as pd
import numpy as np

crime_raw_data = pd.read_csv(file_list[0],
                             usecols=[0,1,2,3], encoding='euc-kr')

crime_station = crime_raw_data.pivot_table(
    crime_raw_data, index=["구분"], columns=["죄종","발생검거"], aggfunc=[np.sum])

crime_station.columns = ['강간검거', '강간', '강도검거', '강도', '살인검거', '살인', '절도검거', '절도', '폭력검거', '폭력']

crime_station['year'] = 2000
crime_station.head()
# Out:
# /tmp/ipykernel_18360/111574292.py:7: FutureWarning: The provided callable <function sum at 0x7fc664508940> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   crime_station = crime_raw_data.pivot_table(
#      강간검거     강간  강도검거    강도  살인검거    살인    절도검거      절도    폭력검거      폭력  year
# 구분
# 강남  147.0  260.0  44.0  63.0  11.0  12.0   770.0  2419.0  2677.0  3073.0  2000
# 강동  144.0  169.0  37.0  38.0  16.0  18.0  1338.0  1970.0  2517.0  2835.0  2000
# 강북  144.0  156.0  30.0  37.0   6.0   7.0   602.0  1381.0  2311.0  2583.0  2000
# 강서  192.0  225.0  66.0  58.0   8.0   7.0  1394.0  2710.0  2790.0  3219.0  2000
# 관악  234.0  403.0  53.0  57.0  13.0  13.0   935.0  2273.0  2971.0  3404.0  2000

# %%
for each_file in file_list:
    print(each_file.split('/')[-1])
# Out:
# 2010.csv
# 2013.csv
# 2012.csv
# 2006.csv
# 2004.csv
# 2007.csv
# 2003.csv
# 2005.csv
# 2017.csv
# 2001.csv
# 2008.csv
# 2015.csv
# 2011.csv
# 2018.csv
# 2016.csv
# 2000.csv
# 2009.csv
# 2014.csv
# 2002.csv

# %%
for each_file in file_list:
    print(each_file.split('/')[-1][:4])
# Out:
# 2010
# 2013
# 2012
# 2006
# 2004
# 2007
# 2003
# 2005
# 2017
# 2001
# 2008
# 2015
# 2011
# 2018
# 2016
# 2000
# 2009
# 2014
# 2002

# %%
crime_station_t = []

for each_file in file_list:
    crime_raw_data = pd.read_csv(each_file, usecols=[0,1,2,3], encoding='euc-kr')

    crime_station = crime_raw_data.pivot_table(
        crime_raw_data, index=["구분"], columns=["죄종","발생검거"], aggfunc=[np.sum])

    crime_station.columns = ['강간검거', '강간', '강도검거', '강도', '살인검거', '살인', '절도검거', '절도', '폭력검거', '폭력']

    crime_station['year'] = each_file.split('/')[-1][:4]

    crime_station.reset_index(inplace=True)
    crime_station_t.append(crime_station)
# Out:
# /tmp/ipykernel_18360/1390615419.py:6: FutureWarning: The provided callable <function sum at 0x7fc664508940> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   crime_station = crime_raw_data.pivot_table(
# /tmp/ipykernel_18360/1390615419.py:6: FutureWarning: The provided callable <function sum at 0x7fc664508940> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   crime_station = crime_raw_data.pivot_table(
# /tmp/ipykernel_18360/1390615419.py:6: FutureWarning: The provided callable <function sum at 0x7fc664508940> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   crime_station = crime_raw_data.pivot_table(
# /tmp/ipykernel_18360/1390615419.py:6: FutureWarning: The provided callable <function sum at 0x7fc664508940> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   crime_station = crime_raw_data.pivot_table(
# /tmp/ipykernel_18360/1390615419.py:6: FutureWarning: The provided callable <function sum at 0x7fc664508940> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   crime_station = crime_raw_data.pivot_table(
# /tmp/ipykernel_18360/1390615419.py:6: FutureWarning: The provided callable <function sum at 0x7fc664508940> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   crime_station = crime_raw_data.pivot_table(
# /tmp/ipykernel_18360/1390615419.py:6: FutureWarning: The provided callable <function sum at 0x7fc664508940> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   crime_station = crime_raw_data.pivot_table(
# /tmp/ipykernel_18360/1390615419.py:6: FutureWarning: The provided callable <function sum at 0x7fc664508940> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   crime_station = crime_raw_data.pivot_table(
# /tmp/ipykernel_18360/1390615419.py:6: FutureWarning: The provided callable <function sum at 0x7fc664508940> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   crime_station = crime_raw_data.pivot_table(
# /tmp/ipykernel_18360/1390615419.py:6: FutureWarning: The provided callable <function sum at 0x7fc664508940> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   crime_station = crime_raw_data.pivot_table(
# /tmp/ipykernel_18360/1390615419.py:6: FutureWarning: The provided callable <function sum at 0x7fc664508940> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   crime_station = crime_raw_data.pivot_table(
# /tmp/ipykernel_18360/1390615419.py:6: FutureWarning: The provided callable <function sum at 0x7fc664508940> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   crime_station = crime_raw_data.pivot_table(
# /tmp/ipykernel_18360/1390615419.py:6: FutureWarning: The provided callable <function sum at 0x7fc664508940> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   crime_station = crime_raw_data.pivot_table(
# /tmp/ipykernel_18360/1390615419.py:6: FutureWarning: The provided callable <function sum at 0x7fc664508940> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   crime_station = crime_raw_data.pivot_table(
# /tmp/ipykernel_18360/1390615419.py:6: FutureWarning: The provided callable <function sum at 0x7fc664508940> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   crime_station = crime_raw_data.pivot_table(
# /tmp/ipykernel_18360/1390615419.py:6: FutureWarning: The provided callable <function sum at 0x7fc664508940> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   crime_station = crime_raw_data.pivot_table(
# /tmp/ipykernel_18360/1390615419.py:6: FutureWarning: The provided callable <function sum at 0x7fc664508940> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   crime_station = crime_raw_data.pivot_table(
# /tmp/ipykernel_18360/1390615419.py:6: FutureWarning: The provided callable <function sum at 0x7fc664508940> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   crime_station = crime_raw_data.pivot_table(
# /tmp/ipykernel_18360/1390615419.py:6: FutureWarning: The provided callable <function sum at 0x7fc664508940> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   crime_station = crime_raw_data.pivot_table(

# %%
len(crime_station_t)
# Out:
# 19

# %%
crime_total = pd.concat(crime_station_t)
crime_total.head()
# Out:
#    구분   강간검거     강간  강도검거    강도  살인검거    살인    절도검거      절도    폭력검거      폭력  \
# 0  강남  147.0  260.0  44.0  63.0  11.0  12.0   770.0  2419.0  2677.0  3073.0
# 1  강동  144.0  169.0  37.0  38.0  16.0  18.0  1338.0  1970.0  2517.0  2835.0
# 2  강북  144.0  156.0  30.0  37.0   6.0   7.0   602.0  1381.0  2311.0  2583.0
# 3  강서  192.0  225.0  66.0  58.0   8.0   7.0  1394.0  2710.0  2790.0  3219.0
# 4  관악  234.0  403.0  53.0  57.0  13.0  13.0   935.0  2273.0  2971.0  3404.0
#
#    year
# 0  2010
# 1  2010
# 2  2010
# 3  2010
# 4  2010

# %%
crime_total_murder = crime_total.pivot(index='year', columns='구분', values='살인')
crime_total_murder
# Out:
# 구분      강남    강동    강북    강서    관악    광진    구로    금천  남대문    노원  ...    수서  \
# year                                                             ...
# 2000   3.0  12.0   9.0   6.0   8.0   2.0  10.0  10.0  3.0   3.0  ...   3.0
# 2001  13.0   9.0   6.0  16.0   3.0  14.0   4.0  13.0  6.0   8.0  ...   4.0
# 2002   3.0   6.0   7.0   8.0   8.0  12.0   4.0  16.0  2.0   7.0  ...   7.0
# 2003   7.0   6.0   9.0   5.0   4.0   6.0   6.0  15.0  2.0   3.0  ...   5.0
# 2004   8.0   7.0  15.0   8.0   0.0  10.0  13.0  16.0  1.0   5.0  ...   6.0
# 2005   8.0   5.0  10.0  10.0   5.0  16.0  10.0  14.0  1.0  10.0  ...   5.0
# 2006   5.0   4.0   5.0  16.0   5.0   7.0  16.0   5.0  2.0   6.0  ...   4.0
# 2007   8.0   7.0  12.0   4.0  13.0   8.0  19.0   6.0  0.0  11.0  ...   4.0
# 2008  10.0   8.0   7.0  18.0  10.0   3.0  22.0   3.0  1.0   3.0  ...   3.0
# 2009  10.0   6.0   7.0  10.0  11.0  11.0  16.0   7.0  2.0  12.0  ...   7.0
# 2010  12.0  18.0   7.0   7.0  13.0  11.0  17.0   8.0  3.0  16.0  ...   2.0
# 2011  15.0   7.0   7.0  18.0  19.0  11.0  12.0  14.0  1.0   8.0  ...   8.0
# 2012   6.0   5.0   3.0  15.0   7.0   6.0   9.0   8.0  1.0   2.0  ...   3.0
# 2013   6.0   9.0   2.0  14.0   7.0   4.0   9.0   6.0  1.0   7.0  ...   6.0
# 2014   8.0   5.0   6.0   8.0   7.0   8.0   3.0   7.0  3.0   5.0  ...   5.0
# 2015   3.0   4.0   7.0   7.0   9.0   4.0   8.0   3.0  1.0  10.0  ...  10.0
# 2016   3.0   4.0   7.0   9.0   6.0   4.0   9.0   6.0  1.0   5.0  ...   2.0
# 2017   6.0   5.0   8.0  11.0   8.0   6.0   7.0   5.0  1.0   4.0  ...   1.0
# 2018   5.0   3.0   8.0  11.0   9.0   7.0   8.0   6.0  1.0   5.0  ...   5.0
#
# 구분      양천   영등포    용산    은평   종로    종암    중랑   중부   혜화
# year
# 2000   5.0   6.0   5.0   2.0  4.0   8.0  13.0  1.0  3.0
# 2001   8.0   7.0   3.0   6.0  3.0  10.0  16.0  0.0  4.0
# 2002   6.0   3.0   2.0   3.0  0.0   5.0   8.0  1.0  4.0
# 2003   7.0   8.0  14.0   5.0  3.0   2.0  11.0  0.0  5.0
# 2004   6.0   5.0   8.0   5.0  1.0   7.0   7.0  2.0  7.0
# 2005  12.0   4.0   9.0   7.0  3.0   6.0  14.0  2.0  2.0
# 2006   5.0  12.0   9.0   3.0  7.0   6.0  11.0  4.0  5.0
# 2007   8.0  13.0   9.0   6.0  5.0   8.0  13.0  4.0  2.0
# 2008  11.0  19.0   7.0   7.0  5.0   5.0   7.0  4.0  3.0
# 2009   8.0  24.0  11.0   5.0  6.0   2.0  15.0  1.0  1.0
# 2010   9.0  34.0   9.0   4.0  5.0   6.0  13.0  5.0  2.0
# 2011   4.0  18.0  13.0  10.0  6.0   4.0  10.0  2.0  2.0
# 2012   5.0  18.0   7.0   4.0  2.0   4.0   9.0  4.0  2.0
# 2013   3.0  14.0   4.0   5.0  2.0   1.0   6.0  0.0  2.0
# 2014   5.0  14.0   1.0   5.0  3.0   2.0  11.0  3.0  0.0
# 2015   3.0  14.0   5.0   1.0  3.0   3.0  13.0  2.0  3.0
# 2016   5.0  13.0   4.0   2.0  4.0   2.0   8.0  2.0  2.0
# 2017   3.0  15.0   1.0   3.0  5.0   2.0   5.0  0.0  2.0
# 2018   2.0  17.0   1.0   4.0  5.0   6.0   4.0  1.0  1.0
#
# [19 rows x 31 columns]

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %config InlineBackend.figure_format = 'retina'

import matplotlib.font_manager as fm
fontpath = '/usr/share/fonts/tretype/nanum/NanumBarunGothc.ttf'
font = fm.FontProperties(fname=fontpath, size=9)

plt.rc('font', family='NanumBarunGothic')

# %%
import seaborn as sns

plt.figure(figsize= (13,10))
sns.heatmap(crime_total_murder,
            annot=True, linewidths=.5, cmap='RdPu')
plt.title('2000년부터 2018년 서울시 구별 살인사건의수')
plt.tight_layout(pad=5)
plt.show()

# %%
crime_total_murder
# Out:
# 구분      강남    강동    강북    강서    관악    광진    구로    금천  남대문    노원  ...    수서  \
# year                                                             ...
# 2000   3.0  12.0   9.0   6.0   8.0   2.0  10.0  10.0  3.0   3.0  ...   3.0
# 2001  13.0   9.0   6.0  16.0   3.0  14.0   4.0  13.0  6.0   8.0  ...   4.0
# 2002   3.0   6.0   7.0   8.0   8.0  12.0   4.0  16.0  2.0   7.0  ...   7.0
# 2003   7.0   6.0   9.0   5.0   4.0   6.0   6.0  15.0  2.0   3.0  ...   5.0
# 2004   8.0   7.0  15.0   8.0   0.0  10.0  13.0  16.0  1.0   5.0  ...   6.0
# 2005   8.0   5.0  10.0  10.0   5.0  16.0  10.0  14.0  1.0  10.0  ...   5.0
# 2006   5.0   4.0   5.0  16.0   5.0   7.0  16.0   5.0  2.0   6.0  ...   4.0
# 2007   8.0   7.0  12.0   4.0  13.0   8.0  19.0   6.0  0.0  11.0  ...   4.0
# 2008  10.0   8.0   7.0  18.0  10.0   3.0  22.0   3.0  1.0   3.0  ...   3.0
# 2009  10.0   6.0   7.0  10.0  11.0  11.0  16.0   7.0  2.0  12.0  ...   7.0
# 2010  12.0  18.0   7.0   7.0  13.0  11.0  17.0   8.0  3.0  16.0  ...   2.0
# 2011  15.0   7.0   7.0  18.0  19.0  11.0  12.0  14.0  1.0   8.0  ...   8.0
# 2012   6.0   5.0   3.0  15.0   7.0   6.0   9.0   8.0  1.0   2.0  ...   3.0
# 2013   6.0   9.0   2.0  14.0   7.0   4.0   9.0   6.0  1.0   7.0  ...   6.0
# 2014   8.0   5.0   6.0   8.0   7.0   8.0   3.0   7.0  3.0   5.0  ...   5.0
# 2015   3.0   4.0   7.0   7.0   9.0   4.0   8.0   3.0  1.0  10.0  ...  10.0
# 2016   3.0   4.0   7.0   9.0   6.0   4.0   9.0   6.0  1.0   5.0  ...   2.0
# 2017   6.0   5.0   8.0  11.0   8.0   6.0   7.0   5.0  1.0   4.0  ...   1.0
# 2018   5.0   3.0   8.0  11.0   9.0   7.0   8.0   6.0  1.0   5.0  ...   5.0
#
# 구분      양천   영등포    용산    은평   종로    종암    중랑   중부   혜화
# year
# 2000   5.0   6.0   5.0   2.0  4.0   8.0  13.0  1.0  3.0
# 2001   8.0   7.0   3.0   6.0  3.0  10.0  16.0  0.0  4.0
# 2002   6.0   3.0   2.0   3.0  0.0   5.0   8.0  1.0  4.0
# 2003   7.0   8.0  14.0   5.0  3.0   2.0  11.0  0.0  5.0
# 2004   6.0   5.0   8.0   5.0  1.0   7.0   7.0  2.0  7.0
# 2005  12.0   4.0   9.0   7.0  3.0   6.0  14.0  2.0  2.0
# 2006   5.0  12.0   9.0   3.0  7.0   6.0  11.0  4.0  5.0
# 2007   8.0  13.0   9.0   6.0  5.0   8.0  13.0  4.0  2.0
# 2008  11.0  19.0   7.0   7.0  5.0   5.0   7.0  4.0  3.0
# 2009   8.0  24.0  11.0   5.0  6.0   2.0  15.0  1.0  1.0
# 2010   9.0  34.0   9.0   4.0  5.0   6.0  13.0  5.0  2.0
# 2011   4.0  18.0  13.0  10.0  6.0   4.0  10.0  2.0  2.0
# 2012   5.0  18.0   7.0   4.0  2.0   4.0   9.0  4.0  2.0
# 2013   3.0  14.0   4.0   5.0  2.0   1.0   6.0  0.0  2.0
# 2014   5.0  14.0   1.0   5.0  3.0   2.0  11.0  3.0  0.0
# 2015   3.0  14.0   5.0   1.0  3.0   3.0  13.0  2.0  3.0
# 2016   5.0  13.0   4.0   2.0  4.0   2.0   8.0  2.0  2.0
# 2017   3.0  15.0   1.0   3.0  5.0   2.0   5.0  0.0  2.0
# 2018   2.0  17.0   1.0   4.0  5.0   6.0   4.0  1.0  1.0
#
# [19 rows x 31 columns]

# %%
crime_total_murder.plot(figsize=(12,10))
# plt.xticks(np.arange(2000, 2019, 1))
plt.show()

# %%
crime_total_murder[['강남', '서초', '영등포']].plot(figsize=(12,10))
plt.show()

# %%
crime_total_violence = crime_total.pivot(index='year', columns='구분', values='폭력')
crime_total_violence[['강남', '서초', '영등포', '노원', '관악']].plot(figsize=(12,10))
plt.show()

# %%
crime_total_sexual = crime_total.pivot(index='year', columns='구분', values='강간')
crime_total_sexual[['강남', '서초', '영등포', '노원', '관악']].plot(figsize=(12,10))
plt.show()
